# %% [markdown]
# <a href="https://colab.research.google.com/github/shivendr7/VFD_NOMA/blob/main/VFD_NOMAMultiModel(trial7)NormalizingEffectWith(tanh).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# !git clone https://shivendr7:trial1@github.com/shivendr7/VFD_NOMA/
df=pd.read_csv('VFD_NOMA/myfile1multi_10850samples.csv')
# Out:
# fatal: destination path 'VFD_NOMA' already exists and is not an empty directory.

# %%
df.head()
# Out:
#       dsr1    dr1r2       Pr2  msr1  ...  mr1r2      zeta  minPr1  minDsr2
# 0  0.27692  0.33232  0.097132     2  ...      1  0.411730  0.9998    0.021
# 1  0.38156  0.83586  0.795200     3  ...      2  0.093436  0.0120    0.264
# 2  0.27603  0.77579  0.655100     2  ...      3  0.081306  0.9998    0.040
# 3  0.22381  0.82589  0.255100     1  ...      2  0.252980  0.0670    0.262
# 4  0.14929  0.48026  0.840720     3  ...      1  0.127140  0.1836    0.196
#
# [5 rows x 11 columns]

# %%
X=np.array(df[df.columns[:9]])
print(X.shape)
X
# Out:
# (10850, 9)
# array([[0.27692 , 0.33232 , 0.097132, ..., 3.      , 1.      , 0.41173 ],
#        [0.38156 , 0.83586 , 0.7952  , ..., 1.      , 2.      , 0.093436],
#        [0.27603 , 0.77579 , 0.6551  , ..., 3.      , 3.      , 0.081306],
#        ...,
#        [0.7774  , 0.50461 , 0.94554 , ..., 1.      , 3.      , 0.35268 ],
#        [0.34322 , 0.56302 , 0.9308  , ..., 1.      , 2.      , 0.14474 ],
#        [0.56928 , 0.81462 , 0.54546 , ..., 3.      , 3.      , 0.35923 ]])

# %%
y=np.array(df[ [df.columns[-2], df.columns[-1]] ])
print(y.shape)
y
# Out:
# (10850, 2)
# array([[0.9998, 0.021 ],
#        [0.012 , 0.264 ],
#        [0.9998, 0.04  ],
#        ...,
#        [0.0043, 0.5   ],
#        [0.0428, 0.495 ],
#        [0.9998, 0.025 ]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=30)
X_train.shape, y_test.shape
# Out:
# ((7269, 9), (3581, 2))

# %%
#Normalizing dataset
std=np.std(X_train, axis=1)
m=np.mean(X_train, axis=1)
std_test=np.std(y_train, axis=1)
m_test=np.mean(y_train, axis=1)
for i in range(9):
  X_train[:, i]=(X_train[:, i]-m[i])/std[i]
  X_test[:, i]=(X_test[:, i]-m[i])/std[i]
for i in range(2):
  y_train[:, i]=(y_train[:, i]-m_test[i])/std_test[i]
  y_test[:, i]=(y_test[:, i]-m_test[i])/std_test[i]

# %%
X_train
# Out:
# array([[-0.88788988, -1.13621833, -0.48357924, ...,  1.09930562,
#          0.67541373, -1.1831505 ],
#        [-0.81057924, -0.68476889, -0.32119661, ..., -0.07867328,
#          0.67541373, -1.16592443],
#        [-0.69301985, -0.90372893, -0.84622383, ...,  1.09930562,
#         -0.29206447, -1.03289006],
#        ...,
#        [-1.24601717, -0.58035644, -1.37670165, ..., -0.07867328,
#          0.67541373, -0.92785853],
#        [-1.42567097, -0.29470123, -0.71967654, ...,  1.09930562,
#         -0.29206447, -1.00063423],
#        [-1.2964658 , -1.06869838, -1.34454786, ...,  2.27728452,
#         -0.29206447, -1.17519356]])

# %%
from keras.models import Model
from keras.layers import BatchNormalization, Dense, Dropout, Input, Concatenate
from keras.optimizers import Adam
from keras.losses import MeanAbsolutePercentageError, Huber
from keras.initializers import HeUniform

# %%
heu=HeUniform(seed=1)
inp=Input(shape=(9, ))
#inp1=BatchNormalization()(inp)
common_layers=Dense(units=128, activation='tanh', kernel_initializer=heu, name='commonLayersD1')(inp)
common_layers=BatchNormalization()(common_layers)
common_layers=Dense(units=128, activation='tanh', kernel_initializer=heu, name='CommonLayersD2')(common_layers)
common_layers=BatchNormalization()(common_layers)

Prmin=Dense(units=64, activation='tanh', kernel_initializer=heu, name='PrminBranchD1')(common_layers)
#Prmin=Dense(units=64, activation='tanh', kernel_initializer=heu, name='PrminBranchD2')(Prmin)
Prmin=Dense(units=32, activation='tanh', kernel_initializer=heu, name='PrminBranchD3')(Prmin)
#Prmin=Dense(units=32, activation='tanh', kernel_initializer=heu)(Prmin)
Prmin=Dense(units=1, activation='tanh', kernel_initializer=heu, name='PrminBranchD4')(Prmin)

Dsrmin=Dense(units=64, activation='tanh', kernel_initializer=heu, name='DsrminBranchD1')(common_layers)
#Dsrmin=Dense(units=64, activation='tanh', kernel_initializer=heu, name='DsrminBranchD2')(Dsrmin)
Dsrmin=Dense(units=32, activation='tanh', kernel_initializer=heu, name='DsrminBranchD3')(Dsrmin)
#Dsrmin=Dense(units=32, activation='tanh', kernel_initializer=heu)(Dsrmin)
Dsrmin=Dense(units=1, activation='tanh', kernel_initializer=heu, name='DsrminBranchD4')(Dsrmin)

out=Concatenate(axis=1)([Prmin, Dsrmin])
model=Model(inputs=inp, outputs=out)
mape=MeanAbsolutePercentageError()
h_loss=Huber(delta=6)
model.compile(optimizer=Adam(learning_rate=0.001), loss=[h_loss, 'mse'])
model.summary()
# Out:
# Model: "model_37"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_38 (InputLayer)           [(None, 9)]          0
# __________________________________________________________________________________________________
# commonLayersD1 (Dense)          (None, 128)          1280        input_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 128)          512         commonLayersD1[0][0]
# __________________________________________________________________________________________________
# CommonLayersD2 (Dense)          (None, 128)          16512       batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 128)          512         CommonLayersD2[0][0]
# __________________________________________________________________________________________________
# PrminBranchD1 (Dense)           (None, 64)           8256        batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# DsrminBranchD1 (Dense)          (None, 64)           8256        batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# PrminBranchD3 (Dense)           (None, 32)           2080        PrminBranchD1[0][0]
# __________________________________________________________________________________________________
# DsrminBranchD3 (Dense)          (None, 32)           2080        DsrminBranchD1[0][0]
# __________________________________________________________________________________________________
# PrminBranchD4 (Dense)           (None, 1)            33          PrminBranchD3[0][0]
# __________________________________________________________________________________________________
# DsrminBranchD4 (Dense)          (None, 1)            33          DsrminBranchD3[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 2)            0           PrminBranchD4[0][0]
#                                                                  DsrminBranchD4[0][0]
# ==================================================================================================
# Total params: 39,554
# Trainable params: 39,042
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model)

# %%
y_train[:, 0].shape, y_train[:, 0].reshape(y_train.shape[0], 1), y_train[:, 0].reshape(y_train.shape[0], 1).shape
# Out:
# ((7269,), array([[-1.       ],
#         [-1.0411215],
#         [ 8.2317757],
#         ...,
#         [-1.0411215],
#         [ 8.2317757],
#         [ 8.2317757]]), (7269, 1))

# %%
#training=model.fit(X_train, y_train[:, 0].reshape(y_train.shape[0], 1), verbose=2, batch_size=2, epochs=10, validation_split=0.3)

# %%
training=model.fit(X_train, y_train, verbose=2, batch_size=64, epochs=100, validation_split=0.3)
# Out:
# Epoch 1/100
# 80/80 - 2s - loss: 5.2192 - val_loss: 5.2304
# Epoch 2/100
# 80/80 - 0s - loss: 5.0239 - val_loss: 5.1501
# Epoch 3/100
# 80/80 - 0s - loss: 5.0118 - val_loss: 5.1270
# Epoch 4/100
# 80/80 - 0s - loss: 5.0172 - val_loss: 5.1167
# Epoch 5/100
# 80/80 - 0s - loss: 5.0091 - val_loss: 5.0960
# Epoch 6/100
# 80/80 - 0s - loss: 4.9995 - val_loss: 5.0974
# Epoch 7/100
# 80/80 - 0s - loss: 4.9924 - val_loss: 5.0856
# Epoch 8/100
# 80/80 - 0s - loss: 4.9966 - val_loss: 5.0938
# Epoch 9/100
# 80/80 - 0s - loss: 4.9875 - val_loss: 5.0881
# Epoch 10/100
# 80/80 - 0s - loss: 4.9907 - val_loss: 5.0901
# Epoch 11/100
# 80/80 - 0s - loss: 4.9928 - val_loss: 5.0976
# Epoch 12/100
# 80/80 - 0s - loss: 4.9846 - val_loss: 5.0887
# Epoch 13/100
# 80/80 - 0s - loss: 4.9867 - val_loss: 5.0839
# Epoch 14/100
# 80/80 - 0s - loss: 4.9865 - val_loss: 5.0785
# Epoch 15/100
# 80/80 - 0s - loss: 4.9868 - val_loss: 5.0862
# Epoch 16/100
# 80/80 - 0s - loss: 4.9844 - val_loss: 5.0870
# Epoch 17/100
# 80/80 - 0s - loss: 4.9857 - val_loss: 5.0796
# Epoch 18/100
# 80/80 - 0s - loss: 4.9799 - val_loss: 5.0798
# Epoch 19/100
# 80/80 - 0s - loss: 4.9815 - val_loss: 5.0799
# Epoch 20/100
# 80/80 - 0s - loss: 4.9758 - val_loss: 5.0795
# Epoch 21/100
# 80/80 - 0s - loss: 4.9738 - val_loss: 5.0789
# Epoch 22/100
# 80/80 - 0s - loss: 4.9740 - val_loss: 5.0758
# Epoch 23/100
# 80/80 - 0s - loss: 4.9737 - val_loss: 5.0740
# Epoch 24/100
# 80/80 - 0s - loss: 4.9792 - val_loss: 5.0758
# Epoch 25/100
# 80/80 - 0s - loss: 4.9733 - val_loss: 5.0791
# Epoch 26/100
# 80/80 - 0s - loss: 4.9752 - val_loss: 5.0798
# Epoch 27/100
# 80/80 - 0s - loss: 4.9716 - val_loss: 5.0767
# Epoch 28/100
# 80/80 - 0s - loss: 4.9693 - val_loss: 5.0747
# Epoch 29/100
# 80/80 - 0s - loss: 4.9725 - val_loss: 5.0783
# Epoch 30/100
# 80/80 - 0s - loss: 4.9727 - val_loss: 5.0744
# Epoch 31/100
# 80/80 - 0s - loss: 4.9735 - val_loss: 5.0698
# Epoch 32/100
# 80/80 - 0s - loss: 4.9743 - val_loss: 5.0718
# Epoch 33/100
# 80/80 - 0s - loss: 4.9758 - val_loss: 5.0738
# Epoch 34/100
# 80/80 - 0s - loss: 4.9698 - val_loss: 5.0732
# Epoch 35/100
# 80/80 - 0s - loss: 4.9706 - val_loss: 5.0767
# Epoch 36/100
# 80/80 - 0s - loss: 4.9713 - val_loss: 5.0741
# Epoch 37/100
# 80/80 - 0s - loss: 4.9711 - val_loss: 5.0735
# Epoch 38/100
# 80/80 - 0s - loss: 4.9700 - val_loss: 5.0762
# Epoch 39/100
# 80/80 - 0s - loss: 4.9694 - val_loss: 5.0747
# Epoch 40/100
# 80/80 - 0s - loss: 4.9651 - val_loss: 5.0697
# Epoch 41/100
# 80/80 - 0s - loss: 4.9679 - val_loss: 5.0707
# Epoch 42/100
# 80/80 - 0s - loss: 4.9684 - val_loss: 5.0655
# Epoch 43/100
# 80/80 - 0s - loss: 4.9653 - val_loss: 5.0699
# Epoch 44/100
# 80/80 - 0s - loss: 4.9663 - val_loss: 5.0743
# Epoch 45/100
# 80/80 - 0s - loss: 4.9693 - val_loss: 5.0764
# Epoch 46/100
# 80/80 - 0s - loss: 4.9711 - val_loss: 5.0715
# Epoch 47/100
# 80/80 - 0s - loss: 4.9638 - val_loss: 5.0720
# Epoch 48/100
# 80/80 - 0s - loss: 4.9666 - val_loss: 5.0684
# Epoch 49/100
# 80/80 - 0s - loss: 4.9692 - val_loss: 5.0744
# Epoch 50/100
# 80/80 - 0s - loss: 4.9672 - val_loss: 5.0693
# Epoch 51/100
# 80/80 - 0s - loss: 4.9630 - val_loss: 5.0723
# Epoch 52/100
# 80/80 - 0s - loss: 4.9685 - val_loss: 5.0715
# Epoch 53/100
# 80/80 - 0s - loss: 4.9672 - val_loss: 5.0678
# Epoch 54/100
# 80/80 - 0s - loss: 4.9675 - val_loss: 5.0655
# Epoch 55/100
# 80/80 - 0s - loss: 4.9662 - val_loss: 5.0725
# Epoch 56/100
# 80/80 - 0s - loss: 4.9623 - val_loss: 5.0658
# Epoch 57/100
# 80/80 - 0s - loss: 4.9653 - val_loss: 5.0682
# Epoch 58/100
# 80/80 - 0s - loss: 4.9611 - val_loss: 5.0658
# Epoch 59/100
# 80/80 - 0s - loss: 4.9612 - val_loss: 5.0746
# Epoch 60/100
# 80/80 - 0s - loss: 4.9634 - val_loss: 5.0830
# Epoch 61/100
# 80/80 - 0s - loss: 4.9622 - val_loss: 5.0677
# Epoch 62/100
# 80/80 - 0s - loss: 4.9637 - val_loss: 5.0678
# Epoch 63/100
# 80/80 - 0s - loss: 4.9671 - val_loss: 5.0760
# Epoch 64/100
# 80/80 - 0s - loss: 4.9606 - val_loss: 5.0705
# Epoch 65/100
# 80/80 - 0s - loss: 4.9612 - val_loss: 5.0668
# Epoch 66/100
# 80/80 - 0s - loss: 4.9627 - val_loss: 5.0703
# Epoch 67/100
# 80/80 - 0s - loss: 4.9604 - val_loss: 5.0654
# Epoch 68/100
# 80/80 - 0s - loss: 4.9624 - val_loss: 5.0653
# Epoch 69/100
# 80/80 - 0s - loss: 4.9628 - val_loss: 5.0706
# Epoch 70/100
# 80/80 - 0s - loss: 4.9642 - val_loss: 5.0675
# Epoch 71/100
# 80/80 - 0s - loss: 4.9670 - val_loss: 5.0676
# Epoch 72/100
# 80/80 - 0s - loss: 4.9610 - val_loss: 5.0743
# Epoch 73/100
# 80/80 - 0s - loss: 4.9578 - val_loss: 5.0667
# Epoch 74/100
# 80/80 - 0s - loss: 4.9587 - val_loss: 5.0773
# Epoch 75/100
# 80/80 - 0s - loss: 4.9610 - val_loss: 5.0716
# Epoch 76/100
# 80/80 - 0s - loss: 4.9606 - val_loss: 5.0680
# Epoch 77/100
# 80/80 - 0s - loss: 4.9615 - val_loss: 5.0687
# Epoch 78/100
# 80/80 - 0s - loss: 4.9604 - val_loss: 5.0686
# Epoch 79/100
# 80/80 - 0s - loss: 4.9595 - val_loss: 5.0662
# Epoch 80/100
# 80/80 - 0s - loss: 4.9590 - val_loss: 5.0712
# Epoch 81/100
# 80/80 - 0s - loss: 4.9589 - val_loss: 5.0726
# Epoch 82/100
# 80/80 - 0s - loss: 4.9575 - val_loss: 5.0676
# Epoch 83/100
# 80/80 - 0s - loss: 4.9599 - val_loss: 5.0658
# Epoch 84/100
# 80/80 - 0s - loss: 4.9628 - val_loss: 5.0682
# Epoch 85/100
# 80/80 - 0s - loss: 4.9598 - val_loss: 5.0663
# Epoch 86/100
# 80/80 - 0s - loss: 4.9663 - val_loss: 5.0683
# Epoch 87/100
# 80/80 - 0s - loss: 4.9613 - val_loss: 5.0686
# Epoch 88/100
# 80/80 - 0s - loss: 4.9600 - val_loss: 5.0707
# Epoch 89/100
# 80/80 - 0s - loss: 4.9585 - val_loss: 5.0668
# Epoch 90/100
# 80/80 - 0s - loss: 4.9598 - val_loss: 5.0679
# Epoch 91/100
# 80/80 - 0s - loss: 4.9573 - val_loss: 5.0657
# Epoch 92/100
# 80/80 - 0s - loss: 4.9592 - val_loss: 5.0640
# Epoch 93/100
# 80/80 - 0s - loss: 4.9562 - val_loss: 5.0652
# Epoch 94/100
# 80/80 - 0s - loss: 4.9561 - val_loss: 5.0652
# Epoch 95/100
# 80/80 - 0s - loss: 4.9552 - val_loss: 5.0668
# Epoch 96/100
# 80/80 - 0s - loss: 4.9562 - val_loss: 5.0732
# Epoch 97/100
# 80/80 - 0s - loss: 4.9581 - val_loss: 5.0660
# Epoch 98/100
# 80/80 - 0s - loss: 4.9561 - val_loss: 5.0698
# Epoch 99/100
# 80/80 - 0s - loss: 4.9568 - val_loss: 5.0742
# Epoch 100/100
# 80/80 - 0s - loss: 4.9599 - val_loss: 5.0674

# %%
#model.predict(X_train[:10]), y_train[:10, 0]

# %%
w=[x.get_weights() for x in model.layers]
import seaborn as sns
Layer_dim=[print(len(layer), end=' ') for layer in w]
#2->Dense 0->Dropout 4->BatchNorm
print()
W=[layer[0].flatten().reshape(-1, 1) for layer in w if len(layer)==2] #getting weights of only the dense layers
len(W)
# Out:
# 0 2 4 2 4 2 2 2 2 2 2 0
# 8

# %%
#plot weights didtribution of dense layers
for i in range(1, 6):
  plt.subplot(1,5,i)
  sns.violinplot(y=W[i-1])
plt.axis('off')
# Out:
# (-0.5, 0.5, -0.6622772778030086, 0.690746899938171)

# %%
import matplotlib.pyplot as plt
train_loss=training.history['loss']
val_loss=training.history['val_loss']
plt.plot(train_loss, label='train_loss')
plt.plot(val_loss, label='test_loss')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
#Visualizing on Test set
Y_test_pred=model.predict(X_test)
y_test[:, 0], Y_test_pred[:, 0], Y_test_pred[:, 0].shape
# Out:
# (array([-0.57850467,  8.2317757 ,  1.16915888, ...,  8.2317757 ,
#         -0.49626168,  3.70841121]),
#  array([-0.5474949 ,  0.99999803,  0.9673496 , ...,  0.9999961 ,
#         -0.5424546 ,  0.99981695], dtype=float32),
#  (3581,))

# %%
# MODEL's SCORE
print(f'HuberLoss={h_loss(y_test, Y_test_pred).numpy()}')
mape=MeanAbsolutePercentageError()
print(f'MeanAbsolutePercentageError={mape(y_test, Y_test_pred)}')
# Out:
# HuberLoss=5.019700527191162
# MeanAbsolutePercentageError=74.37281799316406

# %%
plt.figure(figsize=(10,5))
plt.plot(y_test[:, 0][:200], label='test_set(minPr1)')
plt.plot(Y_test_pred[:, 0][:200], label='test set pred(minPr1)')
plt.legend()

# %%
plt.figure(figsize=(10,5))
plt.plot(y_test[:, 1][:200], label='test_set(minDsr2)')
plt.plot(Y_test_pred[:, 1][:200], label='test set pred(minDsr2)')
plt.legend()
