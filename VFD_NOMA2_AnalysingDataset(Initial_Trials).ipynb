# %% [markdown]
# <a href="https://colab.research.google.com/github/shivendr7/VFD_NOMA/blob/main/VFD_NOMA2_AnalysingDataset(Initial_Trials).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#clone repo into colab sever
# !git clone https://shivendr7:trial1@github.com/shivendr7/VFD_NOMA/
# Out:
# Cloning into 'VFD_NOMA'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15 (delta 4), reused 5 (delta 1), pack-reused 0
# Unpacking objects: 100% (15/15), done.

# %%
#view files in the Repo
# !ls VFD_NOMA
# Out:
# Data_P1_100000samples.csv  README.md
# Data_P1_100samples.csv	   VFD_NOMA_pushFromDriveTogithub.ipynb

# %%
df=pd.read_csv('VFD_NOMA/Data_P1_100000samples.csv')

# %%
df.head()
# Out:
#       dsr1     dsr2     dr1r2      Pr2  ...  mr1D  mr2D     Zr1r2  pr1min
# 0  0.16891  0.99012  0.969010  0.54219  ...     1     3  0.118850  0.0956
# 1  0.69591  0.64120  0.042443  0.88995  ...     1     1  0.164750  0.0010
# 2  0.70607  0.72167  0.116860  0.99005  ...     2     1  0.005106  0.0021
# 3  0.79231  0.20714  0.601470  0.68766  ...     3     1  0.349490  0.0076
# 4  0.62581  0.20463  0.384060  0.60798  ...     2     3  0.120030  0.2320
#
# [5 rows x 10 columns]

# %%
df.columns, df.shape
# Out:
# (Index(['dsr1', 'dsr2', 'dr1r2', 'Pr2', 'msr1', 'msr2', 'mr1D', 'mr2D', 'Zr1r2',
#         'pr1min'],
#        dtype='object'), (100000, 10))

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,20))
for i in range(9):
  plt.subplot(3, 3, 3*(i//3)+i%3+1)
  plt.scatter(df[df.columns[-1]], df[df.columns[i]])
  xaxis=df.columns[i]
  yaxis=df.columns[-1]
  plt.xlabel(df.columns[i])  #xaxis
  plt.ylabel(df.columns[-1])   #yaxis
#This plot shows how does p1min varies with respect to each of its 9 dimensional inputs

# %%
plt.figure(figsize=(20,20))
for i in range(9):
  plt.subplot(3, 3, 3*(i//3)+i%3+1)
  plt.scatter(df[df.columns[-1]][:100], df[df.columns[i]][:100])
  xaxis=df.columns[i]
  yaxis=df.columns[-1]
  plt.xlabel(df.columns[i])  #xaxis
  plt.ylabel(df.columns[-1])   #yaxis
#This plot shows how does p1min varies with respect to each of its 9 dimensional inputs for first 100 points as per dataset

# %%
df.describe(include='all')
# Out:
#                dsr1           dsr2  ...          Zr1r2         pr1min
# count  1.000000e+05  100000.000000  ...  100000.000000  100000.000000
# mean   4.999597e-01       0.501017  ...       0.249911       0.166931
# std    2.884881e-01       0.288589  ...       0.144333       0.306238
# min    2.310000e-07       0.000005  ...       0.000017       0.001000
# 25%    2.510075e-01       0.252738  ...       0.124948       0.003200
# 50%    4.999600e-01       0.500525  ...       0.249445       0.021900
# 75%    7.504725e-01       0.751370  ...       0.375472       0.128600
# max    9.999900e-01       0.999980  ...       0.499990       0.999800
#
# [8 rows x 10 columns]
