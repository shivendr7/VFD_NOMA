# %% [markdown]
# <a href="https://colab.research.google.com/github/shivendr7/VFD_NOMA/blob/main/VFD_NOMAMultiModel(trial6)NormalizingEffect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# !git clone https://shivendr7:trial1@github.com/shivendr7/VFD_NOMA/
df=pd.read_csv('VFD_NOMA/myfile1multi_10850samples.csv')
# Out:
# fatal: destination path 'VFD_NOMA' already exists and is not an empty directory.

# %%
df.head()
# Out:
#       dsr1    dr1r2       Pr2  msr1  ...  mr1r2      zeta  minPr1  minDsr2
# 0  0.27692  0.33232  0.097132     2  ...      1  0.411730  0.9998    0.021
# 1  0.38156  0.83586  0.795200     3  ...      2  0.093436  0.0120    0.264
# 2  0.27603  0.77579  0.655100     2  ...      3  0.081306  0.9998    0.040
# 3  0.22381  0.82589  0.255100     1  ...      2  0.252980  0.0670    0.262
# 4  0.14929  0.48026  0.840720     3  ...      1  0.127140  0.1836    0.196
#
# [5 rows x 11 columns]

# %%
X=np.array(df[df.columns[:9]])
print(X.shape)
X
# Out:
# (10850, 9)
# array([[0.27692 , 0.33232 , 0.097132, ..., 3.      , 1.      , 0.41173 ],
#        [0.38156 , 0.83586 , 0.7952  , ..., 1.      , 2.      , 0.093436],
#        [0.27603 , 0.77579 , 0.6551  , ..., 3.      , 3.      , 0.081306],
#        ...,
#        [0.7774  , 0.50461 , 0.94554 , ..., 1.      , 3.      , 0.35268 ],
#        [0.34322 , 0.56302 , 0.9308  , ..., 1.      , 2.      , 0.14474 ],
#        [0.56928 , 0.81462 , 0.54546 , ..., 3.      , 3.      , 0.35923 ]])

# %%
y=np.array(df[ [df.columns[-2], df.columns[-1]] ])
print(y.shape)
y
# Out:
# (10850, 2)
# array([[0.9998, 0.021 ],
#        [0.012 , 0.264 ],
#        [0.9998, 0.04  ],
#        ...,
#        [0.0043, 0.5   ],
#        [0.0428, 0.495 ],
#        [0.9998, 0.025 ]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=30)
X_train.shape, y_test.shape
# Out:
# ((7269, 9), (3581, 2))

# %%
#Normalizing dataset
std=np.std(X_train, axis=1)
m=np.mean(X_train, axis=1)
std_test=np.std(y_train, axis=1)
m_test=np.mean(y_train, axis=1)
for i in range(9):
  X_train[:, i]=(X_train[:, i]-m[i])/std[i]
  X_test[:, i]=(X_test[:, i]-m[i])/std[i]
for i in range(2):
  y_train[:, i]=(y_train[:, i]-m_test[i])/std_test[i]
  y_test[:, i]=(y_test[:, i]-m_test[i])/std_test[i]

# %%
X_train
# Out:
# array([[-0.88788988, -1.13621833, -0.48357924, ...,  1.09930562,
#          0.67541373, -1.1831505 ],
#        [-0.81057924, -0.68476889, -0.32119661, ..., -0.07867328,
#          0.67541373, -1.16592443],
#        [-0.69301985, -0.90372893, -0.84622383, ...,  1.09930562,
#         -0.29206447, -1.03289006],
#        ...,
#        [-1.24601717, -0.58035644, -1.37670165, ..., -0.07867328,
#          0.67541373, -0.92785853],
#        [-1.42567097, -0.29470123, -0.71967654, ...,  1.09930562,
#         -0.29206447, -1.00063423],
#        [-1.2964658 , -1.06869838, -1.34454786, ...,  2.27728452,
#         -0.29206447, -1.17519356]])

# %%
from keras.models import Model
from keras.layers import BatchNormalization, Dense, Dropout, Input, Concatenate
from keras.optimizers import Adam
from keras.losses import MeanAbsolutePercentageError, Huber
from keras.initializers import HeUniform

# %%
heu=HeUniform(seed=1)
inp=Input(shape=(9, ))
#inp1=BatchNormalization()(inp)
common_layers=Dense(units=128, activation='relu', kernel_initializer=heu, name='commonLayersD1')(inp)
common_layers=BatchNormalization()(common_layers)
common_layers=Dense(units=128, activation='relu', kernel_initializer=heu, name='CommonLayersD2')(common_layers)
common_layers=BatchNormalization()(common_layers)

Prmin=Dense(units=64, activation='relu', kernel_initializer=heu, name='PrminBranchD1')(common_layers)
Prmin=Dense(units=64, activation='relu', kernel_initializer=heu, name='PrminBranchD2')(Prmin)
Prmin=Dense(units=32, activation='relu', kernel_initializer=heu, name='PrminBranchD3')(Prmin)
Prmin=Dense(units=32, activation='relu', kernel_initializer=heu)(Prmin)
Prmin=Dense(units=1, activation='relu', kernel_initializer=heu, name='PrminBranchD4')(Prmin)

Dsrmin=Dense(units=64, activation='relu', kernel_initializer=heu, name='DsrminBranchD1')(common_layers)
Dsrmin=Dense(units=64, activation='relu', kernel_initializer=heu, name='DsrminBranchD2')(Dsrmin)
Dsrmin=Dense(units=32, activation='relu', kernel_initializer=heu, name='DsrminBranchD3')(Dsrmin)
Dsrmin=Dense(units=32, activation='relu', kernel_initializer=heu)(Dsrmin)
Dsrmin=Dense(units=1, activation='relu', kernel_initializer=heu, name='DsrminBranchD4')(Dsrmin)

out=Concatenate(axis=1)([Prmin, Dsrmin])
model=Model(inputs=inp, outputs=out)
mape=MeanAbsolutePercentageError()
h_loss=Huber(delta=4)
model.compile(optimizer=Adam(learning_rate=0.001), loss=[h_loss, 'mse'])
model.summary()
# Out:
# Model: "model_31"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_32 (InputLayer)           [(None, 9)]          0
# __________________________________________________________________________________________________
# commonLayersD1 (Dense)          (None, 128)          1280        input_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 128)          512         commonLayersD1[0][0]
# __________________________________________________________________________________________________
# CommonLayersD2 (Dense)          (None, 128)          16512       batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 128)          512         CommonLayersD2[0][0]
# __________________________________________________________________________________________________
# PrminBranchD1 (Dense)           (None, 64)           8256        batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# DsrminBranchD1 (Dense)          (None, 64)           8256        batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# PrminBranchD2 (Dense)           (None, 64)           4160        PrminBranchD1[0][0]
# __________________________________________________________________________________________________
# DsrminBranchD2 (Dense)          (None, 64)           4160        DsrminBranchD1[0][0]
# __________________________________________________________________________________________________
# PrminBranchD3 (Dense)           (None, 32)           2080        PrminBranchD2[0][0]
# __________________________________________________________________________________________________
# DsrminBranchD3 (Dense)          (None, 32)           2080        DsrminBranchD2[0][0]
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 32)           1056        PrminBranchD3[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 32)           1056        DsrminBranchD3[0][0]
# __________________________________________________________________________________________________
# PrminBranchD4 (Dense)           (None, 1)            33          dense_42[0][0]
# __________________________________________________________________________________________________
# DsrminBranchD4 (Dense)          (None, 1)            33          dense_43[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 2)            0           PrminBranchD4[0][0]
#                                                                  DsrminBranchD4[0][0]
# ==================================================================================================
# Total params: 49,986
# Trainable params: 49,474
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model)

# %%
y_train[:, 0].shape, y_train[:, 0].reshape(y_train.shape[0], 1), y_train[:, 0].reshape(y_train.shape[0], 1).shape
# Out:
# ((7269,), array([[-1.       ],
#         [-1.0411215],
#         [ 8.2317757],
#         ...,
#         [-1.0411215],
#         [ 8.2317757],
#         [ 8.2317757]]), (7269, 1))

# %%
#training=model.fit(X_train, y_train[:, 0].reshape(y_train.shape[0], 1), verbose=2, batch_size=2, epochs=10, validation_split=0.3)

# %%
training=model.fit(X_train, y_train, verbose=2, batch_size=64, epochs=100, validation_split=0.3)
# Out:
# Epoch 1/100
# 80/80 - 3s - loss: 2.1835 - val_loss: 1.8390
# Epoch 2/100
# 80/80 - 0s - loss: 0.8481 - val_loss: 1.0929
# Epoch 3/100
# 80/80 - 0s - loss: 0.6988 - val_loss: 0.8867
# Epoch 4/100
# 80/80 - 0s - loss: 0.6666 - val_loss: 0.7103
# Epoch 5/100
# 80/80 - 0s - loss: 0.6353 - val_loss: 0.6123
# Epoch 6/100
# 80/80 - 0s - loss: 0.6318 - val_loss: 0.5186
# Epoch 7/100
# 80/80 - 0s - loss: 0.5707 - val_loss: 0.5197
# Epoch 8/100
# 80/80 - 0s - loss: 0.5590 - val_loss: 0.6020
# Epoch 9/100
# 80/80 - 0s - loss: 0.5532 - val_loss: 0.5294
# Epoch 10/100
# 80/80 - 0s - loss: 0.5285 - val_loss: 0.5051
# Epoch 11/100
# 80/80 - 0s - loss: 0.5345 - val_loss: 0.5016
# Epoch 12/100
# 80/80 - 0s - loss: 0.5079 - val_loss: 0.4535
# Epoch 13/100
# 80/80 - 0s - loss: 0.5222 - val_loss: 0.4526
# Epoch 14/100
# 80/80 - 0s - loss: 0.4966 - val_loss: 0.4633
# Epoch 15/100
# 80/80 - 0s - loss: 0.5106 - val_loss: 0.4565
# Epoch 16/100
# 80/80 - 0s - loss: 0.4523 - val_loss: 0.4533
# Epoch 17/100
# 80/80 - 0s - loss: 0.4661 - val_loss: 0.5098
# Epoch 18/100
# 80/80 - 0s - loss: 0.4628 - val_loss: 0.4494
# Epoch 19/100
# 80/80 - 0s - loss: 0.4621 - val_loss: 0.4692
# Epoch 20/100
# 80/80 - 0s - loss: 0.4944 - val_loss: 0.4627
# Epoch 21/100
# 80/80 - 0s - loss: 0.4721 - val_loss: 0.5076
# Epoch 22/100
# 80/80 - 0s - loss: 0.4732 - val_loss: 0.5072
# Epoch 23/100
# 80/80 - 0s - loss: 0.4702 - val_loss: 0.4688
# Epoch 24/100
# 80/80 - 0s - loss: 0.4564 - val_loss: 0.4291
# Epoch 25/100
# 80/80 - 0s - loss: 0.4538 - val_loss: 0.4624
# Epoch 26/100
# 80/80 - 0s - loss: 0.4296 - val_loss: 0.4648
# Epoch 27/100
# 80/80 - 0s - loss: 0.4225 - val_loss: 0.4581
# Epoch 28/100
# 80/80 - 0s - loss: 0.4278 - val_loss: 0.4595
# Epoch 29/100
# 80/80 - 0s - loss: 0.4334 - val_loss: 0.4407
# Epoch 30/100
# 80/80 - 0s - loss: 0.4155 - val_loss: 0.4392
# Epoch 31/100
# 80/80 - 0s - loss: 0.4178 - val_loss: 0.4460
# Epoch 32/100
# 80/80 - 0s - loss: 0.3973 - val_loss: 0.4191
# Epoch 33/100
# 80/80 - 0s - loss: 0.3662 - val_loss: 0.4289
# Epoch 34/100
# 80/80 - 0s - loss: 0.4022 - val_loss: 0.4379
# Epoch 35/100
# 80/80 - 0s - loss: 0.3918 - val_loss: 0.4194
# Epoch 36/100
# 80/80 - 0s - loss: 0.3925 - val_loss: 0.4315
# Epoch 37/100
# 80/80 - 0s - loss: 0.3781 - val_loss: 0.4349
# Epoch 38/100
# 80/80 - 0s - loss: 0.3886 - val_loss: 0.4226
# Epoch 39/100
# 80/80 - 0s - loss: 0.4065 - val_loss: 0.4254
# Epoch 40/100
# 80/80 - 0s - loss: 0.4104 - val_loss: 0.4223
# Epoch 41/100
# 80/80 - 0s - loss: 0.3755 - val_loss: 0.4491
# Epoch 42/100
# 80/80 - 0s - loss: 0.3698 - val_loss: 0.4269
# Epoch 43/100
# 80/80 - 0s - loss: 0.3913 - val_loss: 0.4302
# Epoch 44/100
# 80/80 - 0s - loss: 0.3740 - val_loss: 0.4414
# Epoch 45/100
# 80/80 - 0s - loss: 0.3625 - val_loss: 0.4417
# Epoch 46/100
# 80/80 - 0s - loss: 0.3739 - val_loss: 0.4349
# Epoch 47/100
# 80/80 - 0s - loss: 0.3542 - val_loss: 0.4278
# Epoch 48/100
# 80/80 - 0s - loss: 0.3825 - val_loss: 0.4510
# Epoch 49/100
# 80/80 - 0s - loss: 0.3583 - val_loss: 0.4247
# Epoch 50/100
# 80/80 - 0s - loss: 0.3518 - val_loss: 0.4102
# Epoch 51/100
# 80/80 - 0s - loss: 0.3651 - val_loss: 0.4152
# Epoch 52/100
# 80/80 - 0s - loss: 0.3633 - val_loss: 0.4422
# Epoch 53/100
# 80/80 - 0s - loss: 0.3475 - val_loss: 0.4445
# Epoch 54/100
# 80/80 - 0s - loss: 0.3383 - val_loss: 0.4253
# Epoch 55/100
# 80/80 - 0s - loss: 0.3998 - val_loss: 0.4185
# Epoch 56/100
# 80/80 - 0s - loss: 0.3286 - val_loss: 0.4177
# Epoch 57/100
# 80/80 - 0s - loss: 0.3455 - val_loss: 0.4229
# Epoch 58/100
# 80/80 - 0s - loss: 0.3431 - val_loss: 0.4298
# Epoch 59/100
# 80/80 - 0s - loss: 0.3233 - val_loss: 0.4035
# Epoch 60/100
# 80/80 - 0s - loss: 0.3258 - val_loss: 0.4191
# Epoch 61/100
# 80/80 - 0s - loss: 0.3584 - val_loss: 0.4123
# Epoch 62/100
# 80/80 - 0s - loss: 0.3231 - val_loss: 0.4307
# Epoch 63/100
# 80/80 - 0s - loss: 0.3335 - val_loss: 0.4262
# Epoch 64/100
# 80/80 - 0s - loss: 0.3274 - val_loss: 0.4450
# Epoch 65/100
# 80/80 - 0s - loss: 0.3447 - val_loss: 0.4239
# Epoch 66/100
# 80/80 - 0s - loss: 0.3304 - val_loss: 0.4443
# Epoch 67/100
# 80/80 - 0s - loss: 0.3386 - val_loss: 0.4187
# Epoch 68/100
# 80/80 - 0s - loss: 0.3378 - val_loss: 0.4304
# Epoch 69/100
# 80/80 - 0s - loss: 0.3258 - val_loss: 0.4224
# Epoch 70/100
# 80/80 - 0s - loss: 0.3181 - val_loss: 0.4225
# Epoch 71/100
# 80/80 - 0s - loss: 0.3513 - val_loss: 0.4412
# Epoch 72/100
# 80/80 - 0s - loss: 0.3319 - val_loss: 0.4404
# Epoch 73/100
# 80/80 - 0s - loss: 0.3360 - val_loss: 0.4177
# Epoch 74/100
# 80/80 - 0s - loss: 0.3218 - val_loss: 0.4255
# Epoch 75/100
# 80/80 - 0s - loss: 0.3085 - val_loss: 0.4055
# Epoch 76/100
# 80/80 - 0s - loss: 0.3143 - val_loss: 0.4060
# Epoch 77/100
# 80/80 - 0s - loss: 0.3038 - val_loss: 0.4303
# Epoch 78/100
# 80/80 - 0s - loss: 0.3634 - val_loss: 0.4305
# Epoch 79/100
# 80/80 - 0s - loss: 0.3027 - val_loss: 0.4215
# Epoch 80/100
# 80/80 - 0s - loss: 0.3114 - val_loss: 0.4186
# Epoch 81/100
# 80/80 - 0s - loss: 0.2946 - val_loss: 0.3961
# Epoch 82/100
# 80/80 - 0s - loss: 0.2991 - val_loss: 0.4184
# Epoch 83/100
# 80/80 - 0s - loss: 0.3061 - val_loss: 0.3893
# Epoch 84/100
# 80/80 - 0s - loss: 0.3155 - val_loss: 0.4143
# Epoch 85/100
# 80/80 - 0s - loss: 0.3052 - val_loss: 0.4119
# Epoch 86/100
# 80/80 - 0s - loss: 0.3067 - val_loss: 0.4314
# Epoch 87/100
# 80/80 - 0s - loss: 0.2971 - val_loss: 0.4404
# Epoch 88/100
# 80/80 - 0s - loss: 0.2931 - val_loss: 0.3932
# Epoch 89/100
# 80/80 - 0s - loss: 0.3201 - val_loss: 0.4216
# Epoch 90/100
# 80/80 - 0s - loss: 0.3196 - val_loss: 0.4448
# Epoch 91/100
# 80/80 - 0s - loss: 0.3471 - val_loss: 0.4264
# Epoch 92/100
# 80/80 - 0s - loss: 0.3097 - val_loss: 0.4180
# Epoch 93/100
# 80/80 - 0s - loss: 0.3139 - val_loss: 0.4486
# Epoch 94/100
# 80/80 - 0s - loss: 0.3030 - val_loss: 0.4225
# Epoch 95/100
# 80/80 - 0s - loss: 0.3030 - val_loss: 0.4064
# Epoch 96/100
# 80/80 - 0s - loss: 0.3146 - val_loss: 0.3821
# Epoch 97/100
# 80/80 - 0s - loss: 0.3162 - val_loss: 0.4051
# Epoch 98/100
# 80/80 - 0s - loss: 0.3027 - val_loss: 0.4202
# Epoch 99/100
# 80/80 - 0s - loss: 0.2997 - val_loss: 0.4060
# Epoch 100/100
# 80/80 - 0s - loss: 0.2928 - val_loss: 0.4078

# %%
#model.predict(X_train[:10]), y_train[:10, 0]

# %%
w=[x.get_weights() for x in model.layers]
import seaborn as sns
Layer_dim=[print(len(layer), end=' ') for layer in w]
#2->Dense 0->Dropout 4->BatchNorm
print()
W=[layer[0].flatten().reshape(-1, 1) for layer in w if len(layer)==2] #getting weights of only the dense layers
len(W)
# Out:
# 0 2 4 2 4 2 2 2 2 2 2 2 2 2 2 0
# 12

# %%
#plot weights didtribution of dense layers
for i in range(1, 6):
  plt.subplot(1,5,i)
  sns.violinplot(y=W[i-1])
plt.axis('off')
# Out:
# (-0.5, 0.5, -0.7975729508907884, 0.6638203664333909)

# %%
import matplotlib.pyplot as plt
train_loss=training.history['loss']
val_loss=training.history['val_loss']
plt.plot(train_loss, label='train_loss')
plt.plot(val_loss, label='test_loss')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
#Visualizing on Test set
Y_test_pred=model.predict(X_test)
y_test[:, 0], Y_test_pred[:, 0], Y_test_pred[:, 0].shape
# Out:
# (array([-0.57850467,  8.2317757 ,  1.16915888, ...,  8.2317757 ,
#         -0.49626168,  3.70841121]),
#  array([0.       , 8.425672 , 0.7614423, ..., 7.8620934, 0.       ,
#         3.3771532], dtype=float32),
#  (3581,))

# %%
# MODEL's SCORE
print(f'HuberLoss={h_loss(y_test, Y_test_pred).numpy()}')
mape=MeanAbsolutePercentageError()
print(f'MeanAbsolutePercentageError={mape(y_test, Y_test_pred)}')
# Out:
# HuberLoss=0.39141690731048584
# MeanAbsolutePercentageError=88.38433074951172

# %%
plt.figure(figsize=(10,5))
plt.plot(y_test[:, 0][:200], label='test_set(minPr1)')
plt.plot(Y_test_pred[:, 0][:200], label='test set pred(minPr1)')
plt.legend()

# %%
plt.figure(figsize=(10,5))
plt.plot(y_test[:, 1][:200], label='test_set(minDsr2)')
plt.plot(Y_test_pred[:, 1][:200], label='test set pred(minDsr2)')
plt.legend()
