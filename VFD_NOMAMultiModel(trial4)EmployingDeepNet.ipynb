# %% [markdown]
# <a href="https://colab.research.google.com/github/shivendr7/VFD_NOMA/blob/main/VFD_NOMAMultiModel(trial4)EmployingDeepNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# !git clone https://shivendr7:trial1@github.com/shivendr7/VFD_NOMA/
df=pd.read_csv('VFD_NOMA/myfile1multi_10850samples.csv')
# Out:
# fatal: destination path 'VFD_NOMA' already exists and is not an empty directory.

# %%
df.head()
# Out:
#       dsr1    dr1r2       Pr2  msr1  ...  mr1r2      zeta  minPr1  minDsr2
# 0  0.27692  0.33232  0.097132     2  ...      1  0.411730  0.9998    0.021
# 1  0.38156  0.83586  0.795200     3  ...      2  0.093436  0.0120    0.264
# 2  0.27603  0.77579  0.655100     2  ...      3  0.081306  0.9998    0.040
# 3  0.22381  0.82589  0.255100     1  ...      2  0.252980  0.0670    0.262
# 4  0.14929  0.48026  0.840720     3  ...      1  0.127140  0.1836    0.196
#
# [5 rows x 11 columns]

# %%
X=np.array(df[df.columns[:9]])
print(X.shape)
X
# Out:
# (10850, 9)
# array([[0.27692 , 0.33232 , 0.097132, ..., 3.      , 1.      , 0.41173 ],
#        [0.38156 , 0.83586 , 0.7952  , ..., 1.      , 2.      , 0.093436],
#        [0.27603 , 0.77579 , 0.6551  , ..., 3.      , 3.      , 0.081306],
#        ...,
#        [0.7774  , 0.50461 , 0.94554 , ..., 1.      , 3.      , 0.35268 ],
#        [0.34322 , 0.56302 , 0.9308  , ..., 1.      , 2.      , 0.14474 ],
#        [0.56928 , 0.81462 , 0.54546 , ..., 3.      , 3.      , 0.35923 ]])

# %%
y=np.array(df[ [df.columns[-2], df.columns[-1]] ])
print(y.shape)
y
# Out:
# (10850, 2)
# array([[0.9998, 0.021 ],
#        [0.012 , 0.264 ],
#        [0.9998, 0.04  ],
#        ...,
#        [0.0043, 0.5   ],
#        [0.0428, 0.495 ],
#        [0.9998, 0.025 ]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=30)
X_train.shape, y_test.shape
# Out:
# ((7269, 9), (3581, 2))

# %%
from keras.models import Model
from keras.layers import BatchNormalization, Dense, Dropout, Input, Concatenate
from keras.optimizers import Adam
from keras.losses import MeanAbsolutePercentageError, Huber
from keras.initializers import HeUniform

# %%
heu=HeUniform(seed=1)
inp=Input(shape=(9, ))
inp1=BatchNormalization()(inp)
common_layers=Dense(units=81, activation='relu', kernel_initializer=heu, name='commonLayersD1')(inp1)
common_layers=BatchNormalization()(common_layers)
common_layers=Dense(units=81, activation='relu', kernel_initializer=heu, name='CommonLayersD2')(common_layers)
common_layers=BatchNormalization()(common_layers)

Prmin=Dense(units=27, activation='relu', kernel_initializer=heu, name='PrminBranchD1')(common_layers)
Prmin=Dense(units=27, activation='relu', kernel_initializer=heu, name='PrminBranchD2')(Prmin)
Prmin=Dense(units=9, activation='relu', kernel_initializer=heu, name='PrminBranchD3')(Prmin)
Prmin=Dense(units=1, activation='relu', kernel_initializer=heu, name='PrminBranchD4')(Prmin)

Dsrmin=Dense(units=27, activation='relu', kernel_initializer=heu, name='DsrminBranchD1')(common_layers)
Dsrmin=Dense(units=27, activation='relu', kernel_initializer=heu, name='DsrminBranchD2')(Dsrmin)
Dsrmin=Dense(units=9, activation='relu', kernel_initializer=heu, name='DsrminBranchD3')(Dsrmin)
Dsrmin=Dense(units=1, activation='relu', kernel_initializer=heu, name='DsrminBranchD4')(Dsrmin)

out=Concatenate(axis=1)([Prmin, Dsrmin])
model=Model(inputs=inp, outputs=out)
mape=MeanAbsolutePercentageError()
h_loss=Huber(delta=8)
model.compile(optimizer=Adam(learning_rate=0.001), loss=h_loss)
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 9)]          0
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 9)            36          input_5[0][0]
# __________________________________________________________________________________________________
# commonLayersD1 (Dense)          (None, 81)           810         batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 81)           324         commonLayersD1[0][0]
# __________________________________________________________________________________________________
# CommonLayersD2 (Dense)          (None, 81)           6642        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 81)           324         CommonLayersD2[0][0]
# __________________________________________________________________________________________________
# PrminBranchD1 (Dense)           (None, 27)           2214        batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# DsrminBranchD1 (Dense)          (None, 27)           2214        batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# PrminBranchD2 (Dense)           (None, 27)           756         PrminBranchD1[0][0]
# __________________________________________________________________________________________________
# DsrminBranchD2 (Dense)          (None, 27)           756         DsrminBranchD1[0][0]
# __________________________________________________________________________________________________
# PrminBranchD3 (Dense)           (None, 9)            252         PrminBranchD2[0][0]
# __________________________________________________________________________________________________
# DsrminBranchD3 (Dense)          (None, 9)            252         DsrminBranchD2[0][0]
# __________________________________________________________________________________________________
# PrminBranchD4 (Dense)           (None, 1)            10          PrminBranchD3[0][0]
# __________________________________________________________________________________________________
# DsrminBranchD4 (Dense)          (None, 1)            10          DsrminBranchD3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 2)            0           PrminBranchD4[0][0]
#                                                                  DsrminBranchD4[0][0]
# ==================================================================================================
# Total params: 14,600
# Trainable params: 14,258
# Non-trainable params: 342
# __________________________________________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model)

# %%
y_train[:, 0].shape, y_train[:, 0].reshape(y_train.shape[0], 1), y_train[:, 0].reshape(y_train.shape[0], 1).shape
# Out:
# ((7269,), array([[0.012 ],
#         [0.0076],
#         [0.9998],
#         ...,
#         [0.0076],
#         [0.9998],
#         [0.9998]]), (7269, 1))

# %%
#training=model.fit(X_train, y_train[:, 0].reshape(y_train.shape[0], 1), verbose=2, batch_size=2, epochs=10, validation_split=0.3)

# %%
training=model.fit(X_train, y_train, verbose=2, batch_size=64, epochs=100, validation_split=0.3)
# Out:
# Epoch 1/100
# 80/80 - 3s - loss: 0.0520 - val_loss: 0.0478
# Epoch 2/100
# 80/80 - 0s - loss: 0.0203 - val_loss: 0.0223
# Epoch 3/100
# 80/80 - 0s - loss: 0.0148 - val_loss: 0.0124
# Epoch 4/100
# 80/80 - 0s - loss: 0.0119 - val_loss: 0.0098
# Epoch 5/100
# 80/80 - 0s - loss: 0.0108 - val_loss: 0.0087
# Epoch 6/100
# 80/80 - 0s - loss: 0.0100 - val_loss: 0.0081
# Epoch 7/100
# 80/80 - 0s - loss: 0.0097 - val_loss: 0.0075
# Epoch 8/100
# 80/80 - 0s - loss: 0.0082 - val_loss: 0.0073
# Epoch 9/100
# 80/80 - 0s - loss: 0.0092 - val_loss: 0.0070
# Epoch 10/100
# 80/80 - 0s - loss: 0.0079 - val_loss: 0.0067
# Epoch 11/100
# 80/80 - 0s - loss: 0.0074 - val_loss: 0.0067
# Epoch 12/100
# 80/80 - 0s - loss: 0.0075 - val_loss: 0.0061
# Epoch 13/100
# 80/80 - 0s - loss: 0.0076 - val_loss: 0.0064
# Epoch 14/100
# 80/80 - 0s - loss: 0.0070 - val_loss: 0.0056
# Epoch 15/100
# 80/80 - 0s - loss: 0.0066 - val_loss: 0.0057
# Epoch 16/100
# 80/80 - 0s - loss: 0.0066 - val_loss: 0.0054
# Epoch 17/100
# 80/80 - 0s - loss: 0.0060 - val_loss: 0.0051
# Epoch 18/100
# 80/80 - 0s - loss: 0.0065 - val_loss: 0.0055
# Epoch 19/100
# 80/80 - 0s - loss: 0.0062 - val_loss: 0.0051
# Epoch 20/100
# 80/80 - 0s - loss: 0.0060 - val_loss: 0.0054
# Epoch 21/100
# 80/80 - 0s - loss: 0.0066 - val_loss: 0.0055
# Epoch 22/100
# 80/80 - 0s - loss: 0.0053 - val_loss: 0.0047
# Epoch 23/100
# 80/80 - 0s - loss: 0.0064 - val_loss: 0.0050
# Epoch 24/100
# 80/80 - 0s - loss: 0.0061 - val_loss: 0.0046
# Epoch 25/100
# 80/80 - 0s - loss: 0.0055 - val_loss: 0.0046
# Epoch 26/100
# 80/80 - 0s - loss: 0.0057 - val_loss: 0.0048
# Epoch 27/100
# 80/80 - 0s - loss: 0.0055 - val_loss: 0.0048
# Epoch 28/100
# 80/80 - 0s - loss: 0.0055 - val_loss: 0.0045
# Epoch 29/100
# 80/80 - 0s - loss: 0.0050 - val_loss: 0.0046
# Epoch 30/100
# 80/80 - 0s - loss: 0.0053 - val_loss: 0.0048
# Epoch 31/100
# 80/80 - 0s - loss: 0.0051 - val_loss: 0.0043
# Epoch 32/100
# 80/80 - 0s - loss: 0.0052 - val_loss: 0.0042
# Epoch 33/100
# 80/80 - 0s - loss: 0.0046 - val_loss: 0.0042
# Epoch 34/100
# 80/80 - 0s - loss: 0.0047 - val_loss: 0.0042
# Epoch 35/100
# 80/80 - 0s - loss: 0.0047 - val_loss: 0.0045
# Epoch 36/100
# 80/80 - 0s - loss: 0.0048 - val_loss: 0.0042
# Epoch 37/100
# 80/80 - 0s - loss: 0.0051 - val_loss: 0.0040
# Epoch 38/100
# 80/80 - 0s - loss: 0.0049 - val_loss: 0.0041
# Epoch 39/100
# 80/80 - 0s - loss: 0.0042 - val_loss: 0.0040
# Epoch 40/100
# 80/80 - 0s - loss: 0.0048 - val_loss: 0.0042
# Epoch 41/100
# 80/80 - 0s - loss: 0.0052 - val_loss: 0.0042
# Epoch 42/100
# 80/80 - 0s - loss: 0.0046 - val_loss: 0.0040
# Epoch 43/100
# 80/80 - 0s - loss: 0.0047 - val_loss: 0.0041
# Epoch 44/100
# 80/80 - 0s - loss: 0.0045 - val_loss: 0.0039
# Epoch 45/100
# 80/80 - 0s - loss: 0.0043 - val_loss: 0.0041
# Epoch 46/100
# 80/80 - 0s - loss: 0.0043 - val_loss: 0.0043
# Epoch 47/100
# 80/80 - 0s - loss: 0.0045 - val_loss: 0.0044
# Epoch 48/100
# 80/80 - 0s - loss: 0.0040 - val_loss: 0.0043
# Epoch 49/100
# 80/80 - 0s - loss: 0.0038 - val_loss: 0.0037
# Epoch 50/100
# 80/80 - 0s - loss: 0.0040 - val_loss: 0.0039
# Epoch 51/100
# 80/80 - 0s - loss: 0.0039 - val_loss: 0.0039
# Epoch 52/100
# 80/80 - 0s - loss: 0.0041 - val_loss: 0.0037
# Epoch 53/100
# 80/80 - 0s - loss: 0.0035 - val_loss: 0.0039
# Epoch 54/100
# 80/80 - 0s - loss: 0.0037 - val_loss: 0.0039
# Epoch 55/100
# 80/80 - 0s - loss: 0.0042 - val_loss: 0.0044
# Epoch 56/100
# 80/80 - 0s - loss: 0.0040 - val_loss: 0.0042
# Epoch 57/100
# 80/80 - 0s - loss: 0.0043 - val_loss: 0.0039
# Epoch 58/100
# 80/80 - 0s - loss: 0.0037 - val_loss: 0.0037
# Epoch 59/100
# 80/80 - 0s - loss: 0.0038 - val_loss: 0.0039
# Epoch 60/100
# 80/80 - 0s - loss: 0.0036 - val_loss: 0.0038
# Epoch 61/100
# 80/80 - 0s - loss: 0.0039 - val_loss: 0.0044
# Epoch 62/100
# 80/80 - 0s - loss: 0.0043 - val_loss: 0.0046
# Epoch 63/100
# 80/80 - 0s - loss: 0.0036 - val_loss: 0.0039
# Epoch 64/100
# 80/80 - 0s - loss: 0.0036 - val_loss: 0.0039
# Epoch 65/100
# 80/80 - 0s - loss: 0.0034 - val_loss: 0.0043
# Epoch 66/100
# 80/80 - 0s - loss: 0.0033 - val_loss: 0.0036
# Epoch 67/100
# 80/80 - 0s - loss: 0.0041 - val_loss: 0.0038
# Epoch 68/100
# 80/80 - 0s - loss: 0.0044 - val_loss: 0.0038
# Epoch 69/100
# 80/80 - 0s - loss: 0.0038 - val_loss: 0.0039
# Epoch 70/100
# 80/80 - 0s - loss: 0.0038 - val_loss: 0.0045
# Epoch 71/100
# 80/80 - 0s - loss: 0.0032 - val_loss: 0.0040
# Epoch 72/100
# 80/80 - 0s - loss: 0.0035 - val_loss: 0.0040
# Epoch 73/100
# 80/80 - 0s - loss: 0.0035 - val_loss: 0.0038
# Epoch 74/100
# 80/80 - 0s - loss: 0.0036 - val_loss: 0.0039
# Epoch 75/100
# 80/80 - 0s - loss: 0.0038 - val_loss: 0.0039
# Epoch 76/100
# 80/80 - 0s - loss: 0.0034 - val_loss: 0.0039
# Epoch 77/100
# 80/80 - 0s - loss: 0.0037 - val_loss: 0.0037
# Epoch 78/100
# 80/80 - 0s - loss: 0.0035 - val_loss: 0.0038
# Epoch 79/100
# 80/80 - 0s - loss: 0.0039 - val_loss: 0.0038
# Epoch 80/100
# 80/80 - 0s - loss: 0.0037 - val_loss: 0.0036
# Epoch 81/100
# 80/80 - 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 82/100
# 80/80 - 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 83/100
# 80/80 - 0s - loss: 0.0035 - val_loss: 0.0036
# Epoch 84/100
# 80/80 - 0s - loss: 0.0032 - val_loss: 0.0038
# Epoch 85/100
# 80/80 - 0s - loss: 0.0032 - val_loss: 0.0037
# Epoch 86/100
# 80/80 - 0s - loss: 0.0033 - val_loss: 0.0038
# Epoch 87/100
# 80/80 - 0s - loss: 0.0031 - val_loss: 0.0036
# Epoch 88/100
# 80/80 - 0s - loss: 0.0035 - val_loss: 0.0041
# Epoch 89/100
# 80/80 - 0s - loss: 0.0033 - val_loss: 0.0040
# Epoch 90/100
# 80/80 - 0s - loss: 0.0033 - val_loss: 0.0040
# Epoch 91/100
# 80/80 - 0s - loss: 0.0031 - val_loss: 0.0040
# Epoch 92/100
# 80/80 - 0s - loss: 0.0033 - val_loss: 0.0037
# Epoch 93/100
# 80/80 - 0s - loss: 0.0033 - val_loss: 0.0040
# Epoch 94/100
# 80/80 - 0s - loss: 0.0031 - val_loss: 0.0040
# Epoch 95/100
# 80/80 - 0s - loss: 0.0034 - val_loss: 0.0040
# Epoch 96/100
# 80/80 - 0s - loss: 0.0036 - val_loss: 0.0042
# Epoch 97/100
# 80/80 - 0s - loss: 0.0031 - val_loss: 0.0037
# Epoch 98/100
# 80/80 - 0s - loss: 0.0029 - val_loss: 0.0038
# Epoch 99/100
# 80/80 - 0s - loss: 0.0028 - val_loss: 0.0036
# Epoch 100/100
# 80/80 - 0s - loss: 0.0034 - val_loss: 0.0038

# %%
model.predict(X_train[:10]), y_train[:10, 0]
# Out:
# (array([[0.        , 0.21549174],
#         [0.        , 0.754863  ],
#         [0.9412607 , 0.07231683],
#         [0.        , 0.05639744],
#         [0.86980575, 0.16700473],
#         [0.14829196, 0.56561184],
#         [0.        , 0.36337876],
#         [1.028305  , 0.05525645],
#         [0.00647105, 0.3515406 ],
#         [1.0539376 , 0.        ]], dtype=float32),
#  array([0.012 , 0.0076, 0.9998, 0.001 , 0.9382, 0.1462, 0.0021, 0.9998,
#         0.0285, 0.9998]))

# %%
w=[x.get_weights() for x in model.layers]
import seaborn as sns
Layer_dim=[print(len(layer), end=' ') for layer in w]
#2->Dense 0->Dropout 4->BatchNorm
print()
W=[layer[0].flatten().reshape(-1, 1) for layer in w if len(layer)==2] #getting weights of only the dense layers
len(W)
# Out:
# 0 4 2 4 2 4 2 2 2 2 2 2 2 2 0
# 10

# %%
for i in range(1, 6):
  plt.subplot(1,5,i)
  sns.violinplot(y=W[i-1])
plt.axis('off')
# Out:
# (-0.5, 0.5, -0.9744434293559145, 0.7686610158732485)

# %%
import matplotlib.pyplot as plt
train_loss=training.history['loss']
val_loss=training.history['val_loss']
plt.plot(train_loss, label='train_loss')
plt.plot(val_loss, label='test_loss')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
#Visualizing on Test set
Y_test_pred=model.predict(X_test)
y_test[:, 0], Y_test_pred[:, 0], Y_test_pred[:, 0].shape
# Out:
# (array([0.0571, 0.9998, 0.2441, ..., 0.9998, 0.0659, 0.5158]),
#  array([0.02591321, 0.9993174 , 0.1654892 , ..., 1.0033157 , 0.04064654,
#         0.48597193], dtype=float32),
#  (3581,))

# %%
# MODEL's SCORE
print(f'HuberLoss={h_loss(y_test, Y_test_pred).numpy()}')
mape=MeanAbsolutePercentageError()
print(f'MeanAbsolutePercentageError={mape(y_test, Y_test_pred)}')
# Out:
# HuberLoss=0.003939877264201641
# MeanAbsolutePercentageError=61.72332000732422

# %%
plt.figure(figsize=(10,5))
plt.plot(y_test[:, 0][:200], label='test_set(minPr1)')
plt.plot(Y_test_pred[:, 0][:200], label='test set pred(minPr1)')
plt.legend()

# %%
plt.figure(figsize=(10,5))
plt.plot(y_test[:, 1][:200], label='test_set(minDsr2)')
plt.plot(Y_test_pred[:, 1][:200], label='test set pred(minDsr2)')
plt.legend()
