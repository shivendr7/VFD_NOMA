# %% [markdown]
# <a href="https://colab.research.google.com/github/shivendr7/VFD_NOMA/blob/main/VFD_NOMAMultiModel(trial6)NormalizingEffect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# !git clone https://shivendr7:trial1@github.com/shivendr7/VFD_NOMA/
df=pd.read_csv('VFD_NOMA/myfile1multi_10850samples.csv')
# Out:
# Cloning into 'VFD_NOMA'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (127/127), done.
# remote: Total 131 (delta 53), reused 11 (delta 3), pack-reused 0
# Receiving objects: 100% (131/131), 11.04 MiB | 16.08 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
df.head()
# Out:
#       dsr1    dr1r2       Pr2  msr1  ...  mr1r2      zeta  minPr1  minDsr2
# 0  0.27692  0.33232  0.097132     2  ...      1  0.411730  0.9998    0.021
# 1  0.38156  0.83586  0.795200     3  ...      2  0.093436  0.0120    0.264
# 2  0.27603  0.77579  0.655100     2  ...      3  0.081306  0.9998    0.040
# 3  0.22381  0.82589  0.255100     1  ...      2  0.252980  0.0670    0.262
# 4  0.14929  0.48026  0.840720     3  ...      1  0.127140  0.1836    0.196
#
# [5 rows x 11 columns]

# %%
X=np.array(df[df.columns[:9]])
print(X.shape)
X
# Out:
# (10850, 9)
# array([[0.27692 , 0.33232 , 0.097132, ..., 3.      , 1.      , 0.41173 ],
#        [0.38156 , 0.83586 , 0.7952  , ..., 1.      , 2.      , 0.093436],
#        [0.27603 , 0.77579 , 0.6551  , ..., 3.      , 3.      , 0.081306],
#        ...,
#        [0.7774  , 0.50461 , 0.94554 , ..., 1.      , 3.      , 0.35268 ],
#        [0.34322 , 0.56302 , 0.9308  , ..., 1.      , 2.      , 0.14474 ],
#        [0.56928 , 0.81462 , 0.54546 , ..., 3.      , 3.      , 0.35923 ]])

# %%
y=np.array(df[ [df.columns[-2], df.columns[-1]] ])
print(y.shape)
y
# Out:
# (10850, 2)
# array([[0.9998, 0.021 ],
#        [0.012 , 0.264 ],
#        [0.9998, 0.04  ],
#        ...,
#        [0.0043, 0.5   ],
#        [0.0428, 0.495 ],
#        [0.9998, 0.025 ]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=30)
X_train.shape, y_test.shape
# Out:
# ((7269, 9), (3581, 2))

# %%
#Normalizing dataset
std=np.std(X_train, axis=0)
m=np.mean(X_train, axis=0)
std_test=np.std(y_train, axis=0)
m_test=np.mean(y_train, axis=0)
for i in range(9):
  X_train[:, i]=(X_train[:, i]-m[i])/std[i]
  X_test[:, i]=(X_test[:, i]-m[i])/std[i]
for i in range(2):
  y_train[:, i]=(y_train[:, i]-m_test[i])/std_test[i]
  y_test[:, i]=(y_test[:, i]-m_test[i])/std_test[i]

# %%
X_train
# Out:
# array([[ 5.65318023e-01, -9.03999199e-01,  1.20432557e+00, ...,
#         -2.70309131e-03, -3.36353462e-04, -8.76345158e-01],
#        [ 8.38784019e-01,  5.03819764e-01,  1.66820443e+00, ...,
#         -1.23075126e+00, -3.36353462e-04, -7.48416527e-01],
#        [ 1.25461934e+00, -1.78994443e-01,  1.68357918e-01, ...,
#         -2.70309131e-03, -1.22281301e+00,  2.39557419e-01],
#        ...,
#        [-7.01462758e-01,  8.29423960e-01, -1.34705935e+00, ...,
#         -1.23075126e+00, -3.36353462e-04,  1.01956959e+00],
#        [-1.33694067e+00,  1.72022323e+00,  5.29865863e-01, ...,
#         -2.70309131e-03, -1.22281301e+00,  4.79103953e-01],
#        [-8.79911498e-01, -6.93442148e-01, -1.25520553e+00, ...,
#          1.22534508e+00, -1.22281301e+00, -8.17253327e-01]])

# %%
from keras.models import Model
from keras.layers import BatchNormalization, Dense, Dropout, Input, Concatenate
from keras.optimizers import Adam
from keras.losses import MeanAbsolutePercentageError, Huber
from keras.initializers import HeUniform

# %%
heu=HeUniform(seed=1)
inp=Input(shape=(9, ))
#inp1=BatchNormalization()(inp)
common_layers=Dense(units=128, activation='relu', kernel_initializer=heu, name='commonLayersD1')(inp)
common_layers=BatchNormalization()(common_layers)
common_layers=Dense(units=128, activation='relu', kernel_initializer=heu, name='CommonLayersD2')(common_layers)
common_layers=BatchNormalization()(common_layers)

Prmin=Dense(units=64, activation='relu', kernel_initializer=heu, name='PrminBranchD1')(common_layers)
Prmin=Dense(units=64, activation='relu', kernel_initializer=heu, name='PrminBranchD2')(Prmin)
Prmin=Dense(units=32, activation='relu', kernel_initializer=heu, name='PrminBranchD3')(Prmin)
Prmin=Dense(units=32, activation='relu', kernel_initializer=heu)(Prmin)
Prmin=Dense(units=1, name='PrminBranchD4')(Prmin)

Dsrmin=Dense(units=64, activation='relu', kernel_initializer=heu, name='DsrminBranchD1')(common_layers)
Dsrmin=Dense(units=64, activation='relu', kernel_initializer=heu, name='DsrminBranchD2')(Dsrmin)
Dsrmin=Dense(units=32, activation='relu', kernel_initializer=heu, name='DsrminBranchD3')(Dsrmin)
Dsrmin=Dense(units=32, activation='relu', kernel_initializer=heu)(Dsrmin)
Dsrmin=Dense(units=1, name='DsrminBranchD4')(Dsrmin)

out=Concatenate(axis=1)([Prmin, Dsrmin])
model=Model(inputs=inp, outputs=out)
mape=MeanAbsolutePercentageError()
h_loss=Huber(delta=4)
model.compile(optimizer=Adam(learning_rate=0.001), loss=[h_loss, 'mse'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 9)]          0
# __________________________________________________________________________________________________
# commonLayersD1 (Dense)          (None, 128)          1280        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128)          512         commonLayersD1[0][0]
# __________________________________________________________________________________________________
# CommonLayersD2 (Dense)          (None, 128)          16512       batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128)          512         CommonLayersD2[0][0]
# __________________________________________________________________________________________________
# PrminBranchD1 (Dense)           (None, 64)           8256        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# DsrminBranchD1 (Dense)          (None, 64)           8256        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# PrminBranchD2 (Dense)           (None, 64)           4160        PrminBranchD1[0][0]
# __________________________________________________________________________________________________
# DsrminBranchD2 (Dense)          (None, 64)           4160        DsrminBranchD1[0][0]
# __________________________________________________________________________________________________
# PrminBranchD3 (Dense)           (None, 32)           2080        PrminBranchD2[0][0]
# __________________________________________________________________________________________________
# DsrminBranchD3 (Dense)          (None, 32)           2080        DsrminBranchD2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           1056        PrminBranchD3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           1056        DsrminBranchD3[0][0]
# __________________________________________________________________________________________________
# PrminBranchD4 (Dense)           (None, 1)            33          dense[0][0]
# __________________________________________________________________________________________________
# DsrminBranchD4 (Dense)          (None, 1)            33          dense_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2)            0           PrminBranchD4[0][0]
#                                                                  DsrminBranchD4[0][0]
# ==================================================================================================
# Total params: 49,986
# Trainable params: 49,474
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model)

# %%
y_train[:, 0].shape, y_train[:, 0].reshape(y_train.shape[0], 1), y_train[:, 0].reshape(y_train.shape[0], 1).shape
# Out:
# ((7269,), array([[-0.96051479],
#         [-0.97024854],
#         [ 1.22471198],
#         ...,
#         [-0.97024854],
#         [ 1.22471198],
#         [ 1.22471198]]), (7269, 1))

# %%
#training=model.fit(X_train, y_train[:, 0].reshape(y_train.shape[0], 1), verbose=2, batch_size=2, epochs=10, validation_split=0.3)

# %%
training=model.fit(X_train, y_train, verbose=2, batch_size=64, epochs=100, validation_split=0.3)
# Out:
# Epoch 1/100
# 80/80 - 19s - loss: 0.2065 - val_loss: 0.1303
# Epoch 2/100
# 80/80 - 0s - loss: 0.0771 - val_loss: 0.0675
# Epoch 3/100
# 80/80 - 0s - loss: 0.0620 - val_loss: 0.0509
# Epoch 4/100
# 80/80 - 0s - loss: 0.0534 - val_loss: 0.0454
# Epoch 5/100
# 80/80 - 0s - loss: 0.0517 - val_loss: 0.0509
# Epoch 6/100
# 80/80 - 0s - loss: 0.0416 - val_loss: 0.0363
# Epoch 7/100
# 80/80 - 0s - loss: 0.0426 - val_loss: 0.0402
# Epoch 8/100
# 80/80 - 0s - loss: 0.0383 - val_loss: 0.0380
# Epoch 9/100
# 80/80 - 0s - loss: 0.0369 - val_loss: 0.0339
# Epoch 10/100
# 80/80 - 0s - loss: 0.0436 - val_loss: 0.0382
# Epoch 11/100
# 80/80 - 0s - loss: 0.0334 - val_loss: 0.0342
# Epoch 12/100
# 80/80 - 0s - loss: 0.0320 - val_loss: 0.0328
# Epoch 13/100
# 80/80 - 0s - loss: 0.0364 - val_loss: 0.0375
# Epoch 14/100
# 80/80 - 0s - loss: 0.0327 - val_loss: 0.0345
# Epoch 15/100
# 80/80 - 0s - loss: 0.0295 - val_loss: 0.0307
# Epoch 16/100
# 80/80 - 0s - loss: 0.0335 - val_loss: 0.0312
# Epoch 17/100
# 80/80 - 0s - loss: 0.0301 - val_loss: 0.0320
# Epoch 18/100
# 80/80 - 0s - loss: 0.0305 - val_loss: 0.0306
# Epoch 19/100
# 80/80 - 0s - loss: 0.0295 - val_loss: 0.0321
# Epoch 20/100
# 80/80 - 0s - loss: 0.0279 - val_loss: 0.0326
# Epoch 21/100
# 80/80 - 0s - loss: 0.0263 - val_loss: 0.0294
# Epoch 22/100
# 80/80 - 0s - loss: 0.0247 - val_loss: 0.0322
# Epoch 23/100
# 80/80 - 0s - loss: 0.0262 - val_loss: 0.0312
# Epoch 24/100
# 80/80 - 0s - loss: 0.0262 - val_loss: 0.0313
# Epoch 25/100
# 80/80 - 0s - loss: 0.0247 - val_loss: 0.0363
# Epoch 26/100
# 80/80 - 0s - loss: 0.0244 - val_loss: 0.0297
# Epoch 27/100
# 80/80 - 0s - loss: 0.0223 - val_loss: 0.0307
# Epoch 28/100
# 80/80 - 0s - loss: 0.0223 - val_loss: 0.0315
# Epoch 29/100
# 80/80 - 0s - loss: 0.0205 - val_loss: 0.0289
# Epoch 30/100
# 80/80 - 0s - loss: 0.0221 - val_loss: 0.0304
# Epoch 31/100
# 80/80 - 0s - loss: 0.0229 - val_loss: 0.0321
# Epoch 32/100
# 80/80 - 0s - loss: 0.0193 - val_loss: 0.0300
# Epoch 33/100
# 80/80 - 0s - loss: 0.0225 - val_loss: 0.0302
# Epoch 34/100
# 80/80 - 0s - loss: 0.0205 - val_loss: 0.0310
# Epoch 35/100
# 80/80 - 0s - loss: 0.0219 - val_loss: 0.0313
# Epoch 36/100
# 80/80 - 0s - loss: 0.0208 - val_loss: 0.0302
# Epoch 37/100
# 80/80 - 0s - loss: 0.0209 - val_loss: 0.0311
# Epoch 38/100
# 80/80 - 0s - loss: 0.0192 - val_loss: 0.0314
# Epoch 39/100
# 80/80 - 0s - loss: 0.0203 - val_loss: 0.0314
# Epoch 40/100
# 80/80 - 0s - loss: 0.0204 - val_loss: 0.0298
# Epoch 41/100
# 80/80 - 0s - loss: 0.0188 - val_loss: 0.0301
# Epoch 42/100
# 80/80 - 0s - loss: 0.0180 - val_loss: 0.0339
# Epoch 43/100
# 80/80 - 0s - loss: 0.0181 - val_loss: 0.0304
# Epoch 44/100
# 80/80 - 0s - loss: 0.0177 - val_loss: 0.0303
# Epoch 45/100
# 80/80 - 0s - loss: 0.0167 - val_loss: 0.0301
# Epoch 46/100
# 80/80 - 0s - loss: 0.0169 - val_loss: 0.0313
# Epoch 47/100
# 80/80 - 0s - loss: 0.0176 - val_loss: 0.0301
# Epoch 48/100
# 80/80 - 0s - loss: 0.0154 - val_loss: 0.0295
# Epoch 49/100
# 80/80 - 0s - loss: 0.0147 - val_loss: 0.0290
# Epoch 50/100
# 80/80 - 0s - loss: 0.0162 - val_loss: 0.0315
# Epoch 51/100
# 80/80 - 0s - loss: 0.0165 - val_loss: 0.0298
# Epoch 52/100
# 80/80 - 0s - loss: 0.0151 - val_loss: 0.0313
# Epoch 53/100
# 80/80 - 0s - loss: 0.0165 - val_loss: 0.0306
# Epoch 54/100
# 80/80 - 0s - loss: 0.0156 - val_loss: 0.0304
# Epoch 55/100
# 80/80 - 0s - loss: 0.0175 - val_loss: 0.0350
# Epoch 56/100
# 80/80 - 0s - loss: 0.0161 - val_loss: 0.0301
# Epoch 57/100
# 80/80 - 0s - loss: 0.0150 - val_loss: 0.0317
# Epoch 58/100
# 80/80 - 0s - loss: 0.0171 - val_loss: 0.0311
# Epoch 59/100
# 80/80 - 0s - loss: 0.0131 - val_loss: 0.0283
# Epoch 60/100
# 80/80 - 0s - loss: 0.0135 - val_loss: 0.0305
# Epoch 61/100
# 80/80 - 0s - loss: 0.0149 - val_loss: 0.0307
# Epoch 62/100
# 80/80 - 0s - loss: 0.0147 - val_loss: 0.0302
# Epoch 63/100
# 80/80 - 0s - loss: 0.0153 - val_loss: 0.0349
# Epoch 64/100
# 80/80 - 0s - loss: 0.0138 - val_loss: 0.0329
# Epoch 65/100
# 80/80 - 0s - loss: 0.0149 - val_loss: 0.0321
# Epoch 66/100
# 80/80 - 0s - loss: 0.0139 - val_loss: 0.0307
# Epoch 67/100
# 80/80 - 0s - loss: 0.0152 - val_loss: 0.0291
# Epoch 68/100
# 80/80 - 0s - loss: 0.0124 - val_loss: 0.0294
# Epoch 69/100
# 80/80 - 0s - loss: 0.0118 - val_loss: 0.0292
# Epoch 70/100
# 80/80 - 0s - loss: 0.0126 - val_loss: 0.0284
# Epoch 71/100
# 80/80 - 0s - loss: 0.0116 - val_loss: 0.0284
# Epoch 72/100
# 80/80 - 0s - loss: 0.0119 - val_loss: 0.0288
# Epoch 73/100
# 80/80 - 0s - loss: 0.0139 - val_loss: 0.0290
# Epoch 74/100
# 80/80 - 0s - loss: 0.0123 - val_loss: 0.0340
# Epoch 75/100
# 80/80 - 0s - loss: 0.0122 - val_loss: 0.0295
# Epoch 76/100
# 80/80 - 0s - loss: 0.0124 - val_loss: 0.0294
# Epoch 77/100
# 80/80 - 0s - loss: 0.0128 - val_loss: 0.0304
# Epoch 78/100
# 80/80 - 0s - loss: 0.0108 - val_loss: 0.0295
# Epoch 79/100
# 80/80 - 0s - loss: 0.0108 - val_loss: 0.0307
# Epoch 80/100
# 80/80 - 0s - loss: 0.0127 - val_loss: 0.0318
# Epoch 81/100
# 80/80 - 0s - loss: 0.0115 - val_loss: 0.0296
# Epoch 82/100
# 80/80 - 0s - loss: 0.0112 - val_loss: 0.0308
# Epoch 83/100
# 80/80 - 0s - loss: 0.0103 - val_loss: 0.0291
# Epoch 84/100
# 80/80 - 0s - loss: 0.0113 - val_loss: 0.0307
# Epoch 85/100
# 80/80 - 0s - loss: 0.0114 - val_loss: 0.0306
# Epoch 86/100
# 80/80 - 0s - loss: 0.0104 - val_loss: 0.0297
# Epoch 87/100
# 80/80 - 0s - loss: 0.0101 - val_loss: 0.0296
# Epoch 88/100
# 80/80 - 0s - loss: 0.0090 - val_loss: 0.0299
# Epoch 89/100
# 80/80 - 0s - loss: 0.0111 - val_loss: 0.0308
# Epoch 90/100
# 80/80 - 0s - loss: 0.0098 - val_loss: 0.0289
# Epoch 91/100
# 80/80 - 0s - loss: 0.0093 - val_loss: 0.0278
# Epoch 92/100
# 80/80 - 0s - loss: 0.0095 - val_loss: 0.0273
# Epoch 93/100
# 80/80 - 0s - loss: 0.0096 - val_loss: 0.0297
# Epoch 94/100
# 80/80 - 0s - loss: 0.0089 - val_loss: 0.0298
# Epoch 95/100
# 80/80 - 0s - loss: 0.0082 - val_loss: 0.0298
# Epoch 96/100
# 80/80 - 0s - loss: 0.0097 - val_loss: 0.0294
# Epoch 97/100
# 80/80 - 0s - loss: 0.0100 - val_loss: 0.0310
# Epoch 98/100
# 80/80 - 0s - loss: 0.0097 - val_loss: 0.0305
# Epoch 99/100
# 80/80 - 0s - loss: 0.0094 - val_loss: 0.0282
# Epoch 100/100
# 80/80 - 0s - loss: 0.0104 - val_loss: 0.0308

# %%
#model.predict(X_train[:10]), y_train[:10, 0]

# %%
w=[x.get_weights() for x in model.layers]
import seaborn as sns
Layer_dim=[print(len(layer), end=' ') for layer in w]
#2->Dense 0->Dropout 4->BatchNorm
print()
W=[layer[0].flatten().reshape(-1, 1) for layer in w if len(layer)==2] #getting weights of only the dense layers
len(W)
# Out:
# 0 2 4 2 4 2 2 2 2 2 2 2 2 2 2 0
# 12

# %%
#plot weights didtribution of dense layers
for i in range(1, 6):
  plt.subplot(1,5,i)
  sns.violinplot(y=W[i-1])
plt.axis('off')
# Out:
# (-0.5, 0.5, -0.6423417353626383, 0.6201609098907602)

# %%
import matplotlib.pyplot as plt
train_loss=training.history['loss']
val_loss=training.history['val_loss']
plt.plot(train_loss, label='train_loss')
plt.plot(val_loss, label='test_loss')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
#Visualizing on Test set
Y_test_pred=model.predict(X_test)
y_test[:, 0], Y_test_pred[:, 0], Y_test_pred[:, 0].shape
# Out:
# (array([-0.86074386,  1.22471198, -0.44705951, ...,  1.22471198,
#         -0.84127636,  0.15399953]),
#  array([-0.9070069 ,  1.2445706 , -0.53043044, ...,  1.2270646 ,
#         -0.8554007 ,  0.25079757], dtype=float32),
#  (3581,))

# %%
# MODEL's SCORE
print(f'HuberLoss={h_loss(y_test, Y_test_pred).numpy()}')
mape=MeanAbsolutePercentageError()
print(f'MeanAbsolutePercentageError={mape(y_test, Y_test_pred)}')
# Out:
# HuberLoss=0.030788470059633255
# MeanAbsolutePercentageError=49.168758392333984

# %%
plt.figure(figsize=(10,5))
plt.plot(y_test[:, 0][:200], label='test_set(minPr1)')
plt.plot(Y_test_pred[:, 0][:200], label='test set pred(minPr1)')
plt.legend()

# %%
plt.figure(figsize=(10,5))
plt.plot(y_test[:, 1][:200], label='test_set(minDsr2)')
plt.plot(Y_test_pred[:, 1][:200], label='test set pred(minDsr2)')
plt.legend()
