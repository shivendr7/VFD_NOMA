# %% [markdown]
# <a href="https://colab.research.google.com/github/shivendr7/VFD_NOMA/blob/main/VFD_NOMAMultiModel(trial6)NormalizingEffect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# !git clone https://shivendr7:trial1@github.com/shivendr7/VFD_NOMA/
df=pd.read_csv('VFD_NOMA/myfile1multi_10850samples.csv')
# Out:
# Cloning into 'VFD_NOMA'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 110 (delta 46), reused 11 (delta 3), pack-reused 0
# Receiving objects: 100% (110/110), 9.14 MiB | 8.95 MiB/s, done.
# Resolving deltas: 100% (46/46), done.

# %%
df.head()
# Out:
#       dsr1    dr1r2       Pr2  msr1  ...  mr1r2      zeta  minPr1  minDsr2
# 0  0.27692  0.33232  0.097132     2  ...      1  0.411730  0.9998    0.021
# 1  0.38156  0.83586  0.795200     3  ...      2  0.093436  0.0120    0.264
# 2  0.27603  0.77579  0.655100     2  ...      3  0.081306  0.9998    0.040
# 3  0.22381  0.82589  0.255100     1  ...      2  0.252980  0.0670    0.262
# 4  0.14929  0.48026  0.840720     3  ...      1  0.127140  0.1836    0.196
#
# [5 rows x 11 columns]

# %%
X=np.array(df[df.columns[:9]])
print(X.shape)
X
# Out:
# (10850, 9)
# array([[0.27692 , 0.33232 , 0.097132, ..., 3.      , 1.      , 0.41173 ],
#        [0.38156 , 0.83586 , 0.7952  , ..., 1.      , 2.      , 0.093436],
#        [0.27603 , 0.77579 , 0.6551  , ..., 3.      , 3.      , 0.081306],
#        ...,
#        [0.7774  , 0.50461 , 0.94554 , ..., 1.      , 3.      , 0.35268 ],
#        [0.34322 , 0.56302 , 0.9308  , ..., 1.      , 2.      , 0.14474 ],
#        [0.56928 , 0.81462 , 0.54546 , ..., 3.      , 3.      , 0.35923 ]])

# %%
y=np.array(df[ [df.columns[-2], df.columns[-1]] ])
print(y.shape)
y
# Out:
# (10850, 2)
# array([[0.9998, 0.021 ],
#        [0.012 , 0.264 ],
#        [0.9998, 0.04  ],
#        ...,
#        [0.0043, 0.5   ],
#        [0.0428, 0.495 ],
#        [0.9998, 0.025 ]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=30)
X_train.shape, y_test.shape
# Out:
# ((7269, 9), (3581, 2))

# %%
#Normalizing dataset
std=np.std(X_train, axis=1)
m=np.mean(X_train, axis=1)
std_test=np.std(y_train, axis=1)
m_test=np.mean(y_train, axis=1)
for i in range(9):
  X_train[:, i]=(X_train[:, i]-m[i])/std[i]
  X_test[:, i]=(X_test[:, i]-m[i])/std[i]
for i in range(2):
  y_train[:, i]=(y_train[:, i]-m_test[i])/std_test[i]
  y_test[:, i]=(y_test[:, i]-m_test[i])/std_test[i]

# %%
X_train
# Out:
# array([[-0.88788988, -1.13621833, -0.48357924, ...,  1.09930562,
#          0.67541373, -1.1831505 ],
#        [-0.81057924, -0.68476889, -0.32119661, ..., -0.07867328,
#          0.67541373, -1.16592443],
#        [-0.69301985, -0.90372893, -0.84622383, ...,  1.09930562,
#         -0.29206447, -1.03289006],
#        ...,
#        [-1.24601717, -0.58035644, -1.37670165, ..., -0.07867328,
#          0.67541373, -0.92785853],
#        [-1.42567097, -0.29470123, -0.71967654, ...,  1.09930562,
#         -0.29206447, -1.00063423],
#        [-1.2964658 , -1.06869838, -1.34454786, ...,  2.27728452,
#         -0.29206447, -1.17519356]])

# %%
from keras.models import Model
from keras.layers import BatchNormalization, Dense, Dropout, Input, Concatenate
from keras.optimizers import Adam
from keras.losses import MeanAbsolutePercentageError, Huber
from keras.initializers import HeUniform

# %%
heu=HeUniform(seed=1)
inp=Input(shape=(9, ))
#inp1=BatchNormalization()(inp)
common_layers=Dense(units=128, activation='relu', kernel_initializer=heu, name='commonLayersD1')(inp)
common_layers=BatchNormalization()(common_layers)
common_layers=Dense(units=128, activation='relu', kernel_initializer=heu, name='CommonLayersD2')(common_layers)
common_layers=BatchNormalization()(common_layers)

Prmin=Dense(units=64, activation='relu', kernel_initializer=heu, name='PrminBranchD1')(common_layers)
Prmin=Dense(units=64, activation='relu', kernel_initializer=heu, name='PrminBranchD2')(Prmin)
Prmin=Dense(units=32, activation='relu', kernel_initializer=heu, name='PrminBranchD3')(Prmin)
Prmin=Dense(units=32, activation='relu', kernel_initializer=heu)(Prmin)
Prmin=Dense(units=1, name='PrminBranchD4')(Prmin)

Dsrmin=Dense(units=64, activation='relu', kernel_initializer=heu, name='DsrminBranchD1')(common_layers)
Dsrmin=Dense(units=64, activation='relu', kernel_initializer=heu, name='DsrminBranchD2')(Dsrmin)
Dsrmin=Dense(units=32, activation='relu', kernel_initializer=heu, name='DsrminBranchD3')(Dsrmin)
Dsrmin=Dense(units=32, activation='relu', kernel_initializer=heu)(Dsrmin)
Dsrmin=Dense(units=1, name='DsrminBranchD4')(Dsrmin)

out=Concatenate(axis=1)([Prmin, Dsrmin])
model=Model(inputs=inp, outputs=out)
mape=MeanAbsolutePercentageError()
h_loss=Huber(delta=4)
model.compile(optimizer=Adam(learning_rate=0.001), loss=[h_loss, 'mse'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 9)]          0
# __________________________________________________________________________________________________
# commonLayersD1 (Dense)          (None, 128)          1280        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128)          512         commonLayersD1[0][0]
# __________________________________________________________________________________________________
# CommonLayersD2 (Dense)          (None, 128)          16512       batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128)          512         CommonLayersD2[0][0]
# __________________________________________________________________________________________________
# PrminBranchD1 (Dense)           (None, 64)           8256        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# DsrminBranchD1 (Dense)          (None, 64)           8256        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# PrminBranchD2 (Dense)           (None, 64)           4160        PrminBranchD1[0][0]
# __________________________________________________________________________________________________
# DsrminBranchD2 (Dense)          (None, 64)           4160        DsrminBranchD1[0][0]
# __________________________________________________________________________________________________
# PrminBranchD3 (Dense)           (None, 32)           2080        PrminBranchD2[0][0]
# __________________________________________________________________________________________________
# DsrminBranchD3 (Dense)          (None, 32)           2080        DsrminBranchD2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           1056        PrminBranchD3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           1056        DsrminBranchD3[0][0]
# __________________________________________________________________________________________________
# PrminBranchD4 (Dense)           (None, 1)            33          dense[0][0]
# __________________________________________________________________________________________________
# DsrminBranchD4 (Dense)          (None, 1)            33          dense_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2)            0           PrminBranchD4[0][0]
#                                                                  DsrminBranchD4[0][0]
# ==================================================================================================
# Total params: 49,986
# Trainable params: 49,474
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model)

# %%
y_train[:, 0].shape, y_train[:, 0].reshape(y_train.shape[0], 1), y_train[:, 0].reshape(y_train.shape[0], 1).shape
# Out:
# ((7269,), array([[-1.       ],
#         [-1.0411215],
#         [ 8.2317757],
#         ...,
#         [-1.0411215],
#         [ 8.2317757],
#         [ 8.2317757]]), (7269, 1))

# %%
#training=model.fit(X_train, y_train[:, 0].reshape(y_train.shape[0], 1), verbose=2, batch_size=2, epochs=10, validation_split=0.3)

# %%
training=model.fit(X_train, y_train, verbose=2, batch_size=64, epochs=100, validation_split=0.3)
# Out:
# Epoch 1/100
# 80/80 - 20s - loss: 1.8542 - val_loss: 1.6381
# Epoch 2/100
# 80/80 - 0s - loss: 0.6066 - val_loss: 0.9634
# Epoch 3/100
# 80/80 - 0s - loss: 0.5183 - val_loss: 0.5861
# Epoch 4/100
# 80/80 - 0s - loss: 0.4669 - val_loss: 0.4950
# Epoch 5/100
# 80/80 - 0s - loss: 0.4590 - val_loss: 0.4326
# Epoch 6/100
# 80/80 - 0s - loss: 0.4152 - val_loss: 0.3220
# Epoch 7/100
# 80/80 - 0s - loss: 0.3502 - val_loss: 0.3190
# Epoch 8/100
# 80/80 - 0s - loss: 0.3950 - val_loss: 0.4027
# Epoch 9/100
# 80/80 - 0s - loss: 0.3321 - val_loss: 0.2836
# Epoch 10/100
# 80/80 - 0s - loss: 0.3213 - val_loss: 0.2589
# Epoch 11/100
# 80/80 - 0s - loss: 0.2867 - val_loss: 0.2711
# Epoch 12/100
# 80/80 - 0s - loss: 0.3123 - val_loss: 0.3030
# Epoch 13/100
# 80/80 - 0s - loss: 0.2980 - val_loss: 0.2757
# Epoch 14/100
# 80/80 - 0s - loss: 0.2720 - val_loss: 0.2864
# Epoch 15/100
# 80/80 - 0s - loss: 0.2770 - val_loss: 0.3072
# Epoch 16/100
# 80/80 - 0s - loss: 0.2697 - val_loss: 0.2782
# Epoch 17/100
# 80/80 - 0s - loss: 0.2838 - val_loss: 0.2702
# Epoch 18/100
# 80/80 - 0s - loss: 0.2802 - val_loss: 0.2537
# Epoch 19/100
# 80/80 - 0s - loss: 0.2437 - val_loss: 0.2760
# Epoch 20/100
# 80/80 - 0s - loss: 0.2700 - val_loss: 0.2495
# Epoch 21/100
# 80/80 - 0s - loss: 0.2527 - val_loss: 0.2690
# Epoch 22/100
# 80/80 - 0s - loss: 0.2422 - val_loss: 0.3151
# Epoch 23/100
# 80/80 - 0s - loss: 0.2244 - val_loss: 0.2548
# Epoch 24/100
# 80/80 - 0s - loss: 0.2331 - val_loss: 0.2775
# Epoch 25/100
# 80/80 - 0s - loss: 0.2335 - val_loss: 0.2532
# Epoch 26/100
# 80/80 - 0s - loss: 0.2468 - val_loss: 0.3317
# Epoch 27/100
# 80/80 - 0s - loss: 0.2371 - val_loss: 0.2400
# Epoch 28/100
# 80/80 - 0s - loss: 0.2367 - val_loss: 0.2482
# Epoch 29/100
# 80/80 - 0s - loss: 0.1963 - val_loss: 0.2500
# Epoch 30/100
# 80/80 - 0s - loss: 0.1976 - val_loss: 0.2360
# Epoch 31/100
# 80/80 - 0s - loss: 0.2124 - val_loss: 0.2849
# Epoch 32/100
# 80/80 - 0s - loss: 0.2103 - val_loss: 0.2295
# Epoch 33/100
# 80/80 - 0s - loss: 0.2048 - val_loss: 0.2393
# Epoch 34/100
# 80/80 - 0s - loss: 0.2000 - val_loss: 0.2699
# Epoch 35/100
# 80/80 - 0s - loss: 0.2011 - val_loss: 0.3217
# Epoch 36/100
# 80/80 - 0s - loss: 0.2054 - val_loss: 0.2668
# Epoch 37/100
# 80/80 - 0s - loss: 0.2019 - val_loss: 0.2595
# Epoch 38/100
# 80/80 - 0s - loss: 0.1946 - val_loss: 0.2377
# Epoch 39/100
# 80/80 - 0s - loss: 0.1750 - val_loss: 0.2615
# Epoch 40/100
# 80/80 - 0s - loss: 0.1674 - val_loss: 0.2702
# Epoch 41/100
# 80/80 - 0s - loss: 0.1886 - val_loss: 0.2354
# Epoch 42/100
# 80/80 - 0s - loss: 0.1945 - val_loss: 0.2770
# Epoch 43/100
# 80/80 - 0s - loss: 0.1896 - val_loss: 0.2184
# Epoch 44/100
# 80/80 - 0s - loss: 0.1791 - val_loss: 0.2457
# Epoch 45/100
# 80/80 - 0s - loss: 0.1469 - val_loss: 0.2267
# Epoch 46/100
# 80/80 - 0s - loss: 0.1748 - val_loss: 0.2438
# Epoch 47/100
# 80/80 - 0s - loss: 0.1550 - val_loss: 0.2422
# Epoch 48/100
# 80/80 - 0s - loss: 0.1585 - val_loss: 0.2363
# Epoch 49/100
# 80/80 - 0s - loss: 0.1484 - val_loss: 0.2535
# Epoch 50/100
# 80/80 - 0s - loss: 0.1536 - val_loss: 0.2308
# Epoch 51/100
# 80/80 - 0s - loss: 0.1366 - val_loss: 0.2548
# Epoch 52/100
# 80/80 - 0s - loss: 0.1191 - val_loss: 0.2070
# Epoch 53/100
# 80/80 - 0s - loss: 0.1224 - val_loss: 0.2253
# Epoch 54/100
# 80/80 - 0s - loss: 0.1378 - val_loss: 0.2303
# Epoch 55/100
# 80/80 - 0s - loss: 0.1542 - val_loss: 0.2562
# Epoch 56/100
# 80/80 - 0s - loss: 0.1635 - val_loss: 0.2262
# Epoch 57/100
# 80/80 - 0s - loss: 0.1657 - val_loss: 0.2876
# Epoch 58/100
# 80/80 - 0s - loss: 0.1377 - val_loss: 0.2634
# Epoch 59/100
# 80/80 - 0s - loss: 0.1319 - val_loss: 0.2404
# Epoch 60/100
# 80/80 - 0s - loss: 0.1283 - val_loss: 0.2484
# Epoch 61/100
# 80/80 - 0s - loss: 0.1219 - val_loss: 0.2184
# Epoch 62/100
# 80/80 - 0s - loss: 0.1343 - val_loss: 0.2498
# Epoch 63/100
# 80/80 - 0s - loss: 0.1160 - val_loss: 0.2280
# Epoch 64/100
# 80/80 - 0s - loss: 0.1190 - val_loss: 0.2375
# Epoch 65/100
# 80/80 - 0s - loss: 0.1248 - val_loss: 0.2107
# Epoch 66/100
# 80/80 - 0s - loss: 0.1378 - val_loss: 0.2462
# Epoch 67/100
# 80/80 - 0s - loss: 0.1264 - val_loss: 0.2772
# Epoch 68/100
# 80/80 - 0s - loss: 0.1151 - val_loss: 0.2451
# Epoch 69/100
# 80/80 - 0s - loss: 0.1052 - val_loss: 0.2305
# Epoch 70/100
# 80/80 - 0s - loss: 0.1227 - val_loss: 0.2202
# Epoch 71/100
# 80/80 - 0s - loss: 0.1167 - val_loss: 0.2139
# Epoch 72/100
# 80/80 - 0s - loss: 0.1379 - val_loss: 0.2247
# Epoch 73/100
# 80/80 - 0s - loss: 0.1316 - val_loss: 0.2809
# Epoch 74/100
# 80/80 - 0s - loss: 0.1155 - val_loss: 0.2683
# Epoch 75/100
# 80/80 - 0s - loss: 0.1193 - val_loss: 0.2790
# Epoch 76/100
# 80/80 - 0s - loss: 0.1131 - val_loss: 0.2285
# Epoch 77/100
# 80/80 - 0s - loss: 0.1003 - val_loss: 0.2554
# Epoch 78/100
# 80/80 - 0s - loss: 0.1126 - val_loss: 0.2143
# Epoch 79/100
# 80/80 - 0s - loss: 0.1195 - val_loss: 0.2480
# Epoch 80/100
# 80/80 - 0s - loss: 0.0952 - val_loss: 0.2489
# Epoch 81/100
# 80/80 - 0s - loss: 0.0913 - val_loss: 0.2321
# Epoch 82/100
# 80/80 - 0s - loss: 0.0946 - val_loss: 0.2377
# Epoch 83/100
# 80/80 - 0s - loss: 0.1066 - val_loss: 0.2324
# Epoch 84/100
# 80/80 - 0s - loss: 0.1305 - val_loss: 0.2608
# Epoch 85/100
# 80/80 - 0s - loss: 0.1085 - val_loss: 0.2540
# Epoch 86/100
# 80/80 - 0s - loss: 0.1130 - val_loss: 0.2611
# Epoch 87/100
# 80/80 - 0s - loss: 0.1466 - val_loss: 0.2544
# Epoch 88/100
# 80/80 - 0s - loss: 0.1059 - val_loss: 0.3134
# Epoch 89/100
# 80/80 - 0s - loss: 0.1114 - val_loss: 0.2542
# Epoch 90/100
# 80/80 - 0s - loss: 0.1321 - val_loss: 0.2481
# Epoch 91/100
# 80/80 - 0s - loss: 0.1187 - val_loss: 0.2359
# Epoch 92/100
# 80/80 - 0s - loss: 0.0972 - val_loss: 0.2428
# Epoch 93/100
# 80/80 - 0s - loss: 0.1001 - val_loss: 0.2132
# Epoch 94/100
# 80/80 - 0s - loss: 0.1034 - val_loss: 0.2793
# Epoch 95/100
# 80/80 - 0s - loss: 0.1090 - val_loss: 0.2220
# Epoch 96/100
# 80/80 - 0s - loss: 0.1046 - val_loss: 0.2780
# Epoch 97/100
# 80/80 - 0s - loss: 0.1531 - val_loss: 0.2639
# Epoch 98/100
# 80/80 - 0s - loss: 0.1168 - val_loss: 0.2309
# Epoch 99/100
# 80/80 - 0s - loss: 0.0971 - val_loss: 0.2411
# Epoch 100/100
# 80/80 - 0s - loss: 0.0907 - val_loss: 0.2484

# %%
#model.predict(X_train[:10]), y_train[:10, 0]

# %%
w=[x.get_weights() for x in model.layers]
import seaborn as sns
Layer_dim=[print(len(layer), end=' ') for layer in w]
#2->Dense 0->Dropout 4->BatchNorm
print()
W=[layer[0].flatten().reshape(-1, 1) for layer in w if len(layer)==2] #getting weights of only the dense layers
len(W)
# Out:
# 0 2 4 2 4 2 2 2 2 2 2 2 2 2 2 0
# 12

# %%
#plot weights didtribution of dense layers
for i in range(1, 6):
  plt.subplot(1,5,i)
  sns.violinplot(y=W[i-1])
plt.axis('off')
# Out:
# (-0.5, 0.5, -0.7373554186815872, 0.710799344062294)

# %%
import matplotlib.pyplot as plt
train_loss=training.history['loss']
val_loss=training.history['val_loss']
plt.plot(train_loss, label='train_loss')
plt.plot(val_loss, label='test_loss')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
#Visualizing on Test set
Y_test_pred=model.predict(X_test)
y_test[:, 0], Y_test_pred[:, 0], Y_test_pred[:, 0].shape
# Out:
# (array([-0.57850467,  8.2317757 ,  1.16915888, ...,  8.2317757 ,
#         -0.49626168,  3.70841121]),
#  array([-0.38013893,  8.165028  ,  1.107674  , ...,  8.059586  ,
#         -0.1895728 ,  3.892822  ], dtype=float32),
#  (3581,))

# %%
# MODEL's SCORE
print(f'HuberLoss={h_loss(y_test, Y_test_pred).numpy()}')
mape=MeanAbsolutePercentageError()
print(f'MeanAbsolutePercentageError={mape(y_test, Y_test_pred)}')
# Out:
# HuberLoss=0.2251202017068863
# MeanAbsolutePercentageError=74.9383544921875

# %%
plt.figure(figsize=(10,5))
plt.plot(y_test[:, 0][:200], label='test_set(minPr1)')
plt.plot(Y_test_pred[:, 0][:200], label='test set pred(minPr1)')
plt.legend()

# %%
plt.figure(figsize=(10,5))
plt.plot(y_test[:, 1][:200], label='test_set(minDsr2)')
plt.plot(Y_test_pred[:, 1][:200], label='test set pred(minDsr2)')
plt.legend()
